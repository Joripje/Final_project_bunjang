# %%
## 정규표현식 전처리(카테고리별 따로 지정)
def proccessing(df):
    for i in range(len(df)):
        df.feature[i] = re.sub('\W+',' ', df.feature[i].lower())
        df.feature[i] = re.sub('[0-9]',' ', df.feature[i].lower())

    # 한글자 처리(상황따라 변동)
    for info in range(len(df)):
        title = df.feature[info].split(' ')
        temp =''
        for i in title: 
            if len(i) > 1:
                temp = temp + i + ' '
        df.feature[info] = temp
    return(df)

# %% [markdown]
# # 태그추천 매트릭스 생성 파일 호출

# %%
# !!cd /Users/ppangppang/Desktop/ssac/Final_project/3.Recommen_model/
# %run tag_recommend.py
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 평가지표 생성을 위한 DF 생성

# %%
# 작업 목록 df로 불러오기
query_list = ['노트북','에어팟']

total_df = []
for i in range(len(query_list)):
  # 경로지정
  total_df.append(pd.read_csv(f'/Users/ppangppang/Desktop/ssac/Final_project/2.Processed/info/{query_list[i]}.csv'))

# %% [markdown]
# #### 노트북

# %% [markdown]
# ## 기본적인 전처리 및 모델 생성을 위한 DF 생성

# %%
# 카테고리 상태에 따라 cat1, cat2, cat3 미리 좀 거르기
lab = total_df[0]
lab = lab[(lab['cat1']=='디지털/가전')]
lab = lab[(lab['cat2']=='PC/노트북')]
lab = lab[(lab['cat3']=='노트북/넷북') | (lab['cat3']=='기타(PC/노트북)') | (lab['cat3']=='0')]
lab
# Out:
#        product_id                                     title  \
# 2       175915881  삼성 실버 i5 6세대 램 8G SSD 256G 1.29kg 새배터리장착
# 3       175708161               삼성 갤럭시북 플렉스 알파 노트북 스크린 터치 펜
# 6       175915630                   고사양 msi 게이밍 노트북 gtx1650
# 9       175895274              LG 울트라북 ZD360/가벼워 휴대성 좋은 노트북
# 10      175915560          삼성최저가슬림형!!!,노트북(13인치)슬림형노트북 팝니다.
# ...           ...                                       ...
# 29935   168648094                      HP envy13 i5 6세대 노트북
# 29936   168842625                               *2021 그램17*
# 29937   169796266        삼성노트북 NT270E5U 15.6인치 I3-3120m 의정부
# 29938   169137815                     게이밍 노트북 프레데터 헬리오스 500
# 29939   169415756           삼성노트북  I5-3337U 13인치 8G SSD250G
#
#                         keyword    cat1    cat2        cat3  view  \
# 2                     삼성노트북,노트북  디지털/가전  PC/노트북      노트북/넷북     6
# 3          삼성노트북,갤럭시북플,플렉스,펜,이온  디지털/가전  PC/노트북      노트북/넷북    34
# ...

# %%
lab = location(lab) # 지역정보 걸러야 할 경우만 시행
lab = merge_df(lab) # feature, label로 만들기
lab = lab[(lab.label != 'nan') &(lab.label != '')] # label 빈거 지우기
lab.index=range(len(lab))
lab = proccessing(lab) # 특수문자, 한글자 전처리
lab
# Out:
#                                     feature  \
# 0            삼성 실버 세대 ssd kg 새배터리장착 디지털 가전
# 1         삼성 갤럭시북 플렉스 알파 노트북 스크린 터치 디지털 가전
# 2               고사양 msi 게이밍 노트북 gtx 디지털 가전
# 3         lg 울트라북 zd 가벼워 휴대성 좋은 노트북 디지털 가전
# 4      삼성최저가슬림형 노트북 13인치 슬림형노트북 팝니다 디지털 가전
# ...                                     ...
# 16467         미개봉 갤럭시 노트북 북go 판매합니다 디지털 가전
# 16468         asus 게이밍 노트북 배그 로아 가능 디지털 가전
# 16469             노트북 asus rog 제피러스 디지털 가전
# 16470                            그램 디지털 가전
# 16471             게이밍 노트북 프레데터 헬리오스 디지털 가전
#
#                                      label
# 0                                삼성노트북,노트북
# 1                     삼성노트북,갤럭시북플,플렉스,펜,이온
# 2                 게이밍,노트북,로스트아크,gtx1650,게임
# 3                               울트라북,ZD360
# 4                  삼성,삼성노트북,노트북,중고노트북,13인치
# ...                                    ...
# 16467                노트북,Book,북고,galaxy,삼성
# 16468                노트북,배그,로아,게이밍노트북,ASUS
# 16469  제피러스g15,rog노트북,asus노트북,게이밍노트북,대구노트북
# ...

# %% [markdown]
# ## Train,Test DF생성 및 라벨 분류

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(lab['feature'],lab['label'], test_size=0.2,shuffle=True, random_state=42)

# %%
lab_train = pd.DataFrame()
lab_train['feature'] = X_train
lab_train['label'] = y_train
lab_train.index=range(len(lab_train))

lab_test = pd.DataFrame()
lab_test['feature'] = X_test
lab_test['label'] = y_test
lab_test.index=range(len(lab_test))

# %%
lab_train.head(3)
# Out:
#                                 feature      label
# 0  lg 13인치 그램 노트북 13zd950 gx58k 디지털 가전       lg노트북
# 1                      엘지노트북 세대 디지털 가전      노트북,엘지
# 2                         lg lr 디지털 가전   노트북,LG,그램

# %%
lab_test.head(3)
# Out:
#                              feature                            label
# 0                 msi 게이밍노트북 디지털 가전   게이밍노트북,노트북,msi게이밍노트북,msi,msi노트북
# 1      14인치 hd dell 레티튜드 노트북 디지털 가전       델노트북,14인치노트북,노트북,중고노트북,DELL
# 2  ssd탑재 초경량 화면터치가능 태블릿겸 노트북 디지털 가전                     태블릿,노트북,ssd탑재

# %% [markdown]
# # Train으로 태그 추천 모델 생성

# %%
# 모델링
lab_train = split_label(lab_train)
tag_list = tag(lab_train)
lab_matrix = make_matrix(tag_list,lab_train)
lab_matrix
# Out:
#   0%|          | 0/310 [00:00<?, ?it/s]
#      label        10    1008tu      100s    1050ti    1065g7   1070레이더  \
# 0      노트북  0.000616  0.000112  0.000128  0.000096  0.000111  0.000085
# 0    삼성노트북  0.000434  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   게이밍노트북  0.000000  0.000000  0.000000  0.000514  0.000000  0.000000
# 0    중고노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0       삼성  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ..     ...       ...       ...       ...       ...       ...       ...
# 0    넷북노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   삼성노트북5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   라이젠노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0        탭  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   삼성아티브북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#         10sc      10th      10세대  ...  4441s  15ud70n  박음질   방수  kbmt  \
# ...

# %% [markdown]
# ## 관련 없는 feature list 정리해서 train의 feature 전처리

# %%
a=(lab_matrix.columns.to_list())
a
# Out:
# ['label',
#  '04생산',
#  '10',
#  '1008tu',
#  '100s',
#  '100만',
#  '1050ti',
#  '1065g7',
#  '1070레이더',
#  '10sc',
#  '10th',
#  '10세대',
#  '10코어',
#  '10프로',
#  '11',
#  '110',
#  '11300h',
#  '11세대',
#  '11인치',
#  '11인치예엿',
#  '12',
#  '120g',
#  '120대한정',
#  '128',
#  '128g',
#  '128gb',
#  '128기가',
#  '12인치',
#  '13',
#  '13ud70p',
#  '13z94노트북',
#  '13z970',
#  '13z980',
#  '13zd940',
#  '13zd950',
#  '13인치',
#  '13인치ㅡ풀박스',
#  '13인치그램',
#  '13인치노트북',
#  '13인치슬림형',
#  '13인치와',
#  '13인치용',
#  '13인치풀옵션',
#  '13인치형',
#  '14',
#  '144hz',
#  '14u360',
#  '14u53',
#  '14z960',
#  '14z970',
#  '14z980',
#  '14z995',
#  '14zb970',
#  '14zd',
#  '14zd90n',
#  '14zd90p',
#  '14zd90pgx70k',
#  '14zd950',
#  '14년식',
#  '14인치',
#  '15',
#  '15api',
#  '15ikb',
#  '15iml',
#  '15itl6',
#  '15mid',
#  '15u340',
#  '15u47',
#  '15u480',
#  '15u530',
#  '15u560',
#  '15ud490',
#  '15z',
#  '15z95',
#  '15z95n',
#  '15z960',
#  '15z970',
#  '15z980',
#  '15z990',
#  '15zd90n',
#  '15zd960',
# ...

# %%
tt =[]
for i in a:
    if (len(i)>9) and ('맥북' not in i):
        tt.append(i)
print(tt)
# Out:
# ['14zd90pgx70k', '17인치게이밍노트북', '3인치램8기가ssd하드', '6인치윈도우10엑셀한글파워', 'always9팝니다', 'asus게이밍노트북', 'asus고성능라인업', 'bossmonster', 'convertible', 'dell래티튜드7300', 'expertbook', 'gb스페이스그레이세트', 'lg그램15인치노트북', 'lg그램노트북16인치', 'msi게이밍노트북17인치', 'msi게이밍노트북팝니다', 'nvidia840m', 'ssd삼성고사양노트북15', 'travelmate', '게이밍노트북판매합니다', '델e7450고사양놋북', '번개장터최대매입가격', '비닐도안뜯은새제품팝니다', '빠르게팔려고가격내립니다', '삼성notebook', '삼성nt950qcg', '삼성노트북mame겜', '삼성노트북도매및소매합니다', '삼성노트북판매합니다', '삼성오디세이개이밍노트북', '아이디어패드s340', '울트라pc노트북팔라요', '프리미엄아수스비보북노트북', '하이메이드x베이직스', '17인치가성비삼성노트북', '4세대램8ssd256', '삼성노트북9always', '삼성노트북갤러시북이온', '삼성노트북구형충전기', '삼성인기게이밍가성비좋은i', '액정파손노트북수리매매', '어도비프리미어에펙포토샵인코더', 'msi게이밍노트북삽니다', 'msi노트북17인치', 'strix게이밍노트북', '가성비노트북_고스펙i', '게이밍노트북판매해요', '노트북삽니다택도없는가격', '어르신고스톱장기바둑삼성노트북', '에이수스프로아트스튜디오북', '파빌리온게이밍노트북', 'amd외장그래픽장착', 'amd외장그래픽탑재', '라데온외장그래픽장착', '사무인강인터넷문서작업한글', '삼성펜s15인치노트북', 'asus17인치노트북', 'g게이밍노트북팝니다', '14인치노트북미개봉', '고장난노트북매입전문', 'nt550p7c모델', '삼성노트북가성비최고', '4세대15인치노트북ssd', '가성비최고_삼성센스노트북_', '성능최강_에이셔소형노트북', 'lg14
# ...

# %%
             '국내', '국내1위브랜드', '국내정품', '국내판매1위','깔끔하고', '깨끗하고', '데탑하고', '슬림하고', '외관깨끗하고', '이온하고', '하고','갓성비', '강남', '강남노트북판매', '구미','ㄱㄴ', 'ㄱㄴ', '간편', '강추', '같이','업자아님','및500기가하드', '업무및가정', '이쁜', '인강및', '인지', '인차','추천','성능갑', '슬림휴대성갑', '휴대성갑','키로',
             '공유기', '논현동', '무선공유기', '보유수량30대', '시피유i', '아산', '유니바디', '유니크한', '유선', '유심가능', '유초딩용', '유튜브', '유튜브용', '유플러스', '유형', '팔아유','노트북팔기', '되팔아도', '인티', '인하', '잃어버려도', '팔아여', '팔아용','쌔거', '쌔것','흰둥이','19년구매', '2019년구매', '2020구매', '구매', '구매시', '구매한', '구매했던', '용량추가구매', '월구매',
             'i7판매', 'lg노트북판매', 'pro판', 'ssd판매', '개인판매', '개인판매자', '게이밍노트북판매', '끝판왕', '노트북판매', '리퍼노트북판매', '빠른판매', '빠른판매중', '삼성노트북판매', '상판', '새제품판매', '액정판넬', '영문자판', '일괄판매', '일본판', '자판불량', '중고판매', '특가판매', '판매', '판매밑lg', '판매요', '판매자개인', '판매중', '판매하려고', '판매해염', '풀박스판매', '하판', '한글키판스티커', '한성끝판왕', '한정특가판매', '한정판',
             '최강', '최강자','탈거한','고용량배터리', '듀얼배터리', '배터리', '배터리1', '배터리교체', '배터리방전', '배터리사이클1', '배터리상태', '배터리새제품', '배터리신품', '보조배터리', '보조배터리도', '삼성노트북배터리', '새배터리', '새배터리장착', '신품배터리','04생산','생산', '신년맞이','작년', '제조년월','년as', '년구매', '년구입','년연장','모드로', '모든', '모든게임', 'tuf', 'tuf시리즈','겔럭시버즈',
            ]

# %%
a = list(set(a)-set(title_list))
a.sort()
print(a)
print(len(a))
# Out:
# ['078', '10', '100', '1005g1', '1008tu', '100s', '1050g1', '1050ti', '1060', '1060그램', '1065g7', '1070', '1070레이더', '10750h', '10sc', '10th', '10세대', '10코어', '10포함', '10프로', '10회', '11', '110', '11300h', '11세대', '11인치', '11인치예엿', '11홈', '12', '120', '120g', '120대한정', '125g', '128', '128g', '128gb', '128기가', '12기가', '12인치', '13', '13arr', '13u360', '13ud360', '13ud70p', '13z940', '13z94노트북', '13z950', '13z970', '13z980', '13zd', '13zd940', '13zd950', '13년식', '13인치', '13인치그램', '13인치노트북', '13인치슬림형', '13인치와', '13인치용', '13인치풀옵션', '13인치형', '14', '144hz', '144주사율', '14s', '14td90n', '14td90p', '14u360', '14u53', '14x', '14z90n', '14z950', '14z960', '14z970', '14z980', '14z990', '14z995', '14zb970', '14zd', '14zd90n', '14zd90p', '14zd950', '14zd970', '14zd990', '14년식', '14인치', '14인치그램', '14인치노트북', '14인치형', '15', '152', '1558', '15api', '15ikb', '15iml', '15itl6', '15mid', '15n365', '15n540', '15nd540', '15u340', '15u47', '15u480', '15u50p', '15u530', '15u560', '15ud40n', '15ud480', '15ud490'
# ...

# %%
temp = []
dum = ['팜','팝','니다','급','가격','뜨끈','인츠','_','배송','들고','새거','새것','노북','수리','ㅜ','ㅡ',
       '이번','까지','좋고','헤드','명품','고가','저가','질러','짭','세요','구함','교환','좋아','일주일','잘','사용','려요',
       '좋은','할때','볼때','꿀','해요','속도','라요','아요','을','는','은','를','또는','이상','이하','추천','사요','의','랑','됫',
       '됬','됐','됏','무료','마우스','키보드','스피커','사용','쓴','네고','환영','하자','없음','있음','good','할','가성','매우','등',
       '아이폰','갤럭사','만','으로','멕','애눌','에눌','이벤트','인기','서울','익산','전주','대구','인천','진짜','즉시','증정','지금',
       '출장','남음','낮춤','넷플','보증','갤럭스','겔','좋음','나쁨','택배','합니','당','보건','업글','동묘','거북','ㅜ','가방','떨이',
       '분','ㄱㄱ','ㅠ','ㅍ','볍워','있','저렴','완','이쁨','제거','국내','하고','갓','강남','구미','간편','강추','같이','ㄱ','ㄴ','ㄷ',
       '빵','욤','어서','아님','요가','인지','이쁜','및','인차','아산','논현','유','팔','잃','인티','인하','판','최강','탈거','배터리',
       '쌔','쎄','tuf','추천','갑','특가','세일','구매','했','햇','청주','이쁘','이쁜','키로','파우'
       ]
for i in a:
    for j in dum:
        if j in i:
            temp.append(i)
print(temp)
# Out:
# []

# %%
for i in title_list:
    lab['feature'] = lab['feature'].str.replace(i, '')
    lab['label'] = lab['label'].str.replace(i,'')
lab
# Out:
#                                  feature                              label
# 0            삼성 실버 세대 ssd kg 새장착 디지털 가전                           삼성노트북,노트북
# 1      삼성 갤럭시북 플렉스 알파 노트북 스크린 터치 디지털 가전                삼성노트북,갤럭시북플,플렉스,펜,이온
# 2            고사양 msi 게이밍 노트북 gtx 디지털 가전            게이밍,노트북,로스트아크,gtx1650,게임
# 3        lg 울트라북 zd 가벼워 휴대성  노트북 디지털 가전                          울트라북,ZD360
# 4               노트북 13인치 슬림형노트북  디지털 가전             삼성,삼성노트북,노트북,중고노트북,13인치
# ...                                  ...                                ...
# 16467           미개봉 갤럭시 노트북 북go  디지털 가전               노트북,Book,북고,galaxy,삼성
# 16468      asus 게이밍 노트북 배그 로아 가능 디지털 가전               노트북,배그,로아,게이밍노트북,ASUS
# 16469          노트북 asus rog 제피러스 디지털 가전   제피러스g15,rog노트북,asus노트북,게이밍노트북,노트북
# 16470                         그램 디지털 가전                            노트북,lg그램
# 16471          게이밍 노트북 프레데터 헬리오스 디지털 가전                     게이밍,게이밍노트북,1070
#
# [16472 rows x 2 columns]

# %%
# 필요없는 정보 담아서 지우기
# title_list
for i in title_list:
    lab_train['feature'] = lab_train['feature'].str.replace(i, '')
lab_train
# Out:
#                                     feature                          label  \
# 0      lg 13인치 그램 노트북 13zd950 gx58k 디지털 가전                           lg노트북
# 1                          엘지노트북 세대 디지털 가전                          노트북,엘지
# 2                             lg lr 디지털 가전                       노트북,LG,그램
# 3                  dell 노트북 i7 15인치 디지털 가전                 Dell,델,노트북,음악작업
# 4                분 상태 특 레노보 미니 노트북  디지털 가전                          파름신오신날
# ...                                     ...                            ...
# 13172          삼성 노트북9 슬림메탈 i3 13인치 디지털 가전           노트북,슬림,술림메탈,삼성노트북9,i3
# 13173               hp omen 게이밍 노트북 디지털 가전       HPMONE,노트북,게이밍노트북,15인치노트북
# 13174                           노트북 디지털 가전                      파름신오신날,파름신
# 13175                  윈도우 삼성노트북 nt 디지털 가전   윈도우11,삼성노트북,NT305V5A,i5-2450M
# 13176                        삼성노트북  디지털 가전                    삼성,노트북,윈도우10
#
#       label1    label2    label3 label4  label5
# ...

# %% [markdown]
# ## 모델 재성성

# %%
lab_matrix = make_matrix(tag_list,lab_train)
lab_matrix
# Out:
#   0%|          | 0/322 [00:00<?, ?it/s]
#      label        10    1008tu      100s    1050ti    1065g7  1070레이더  \
# 0      노트북  0.000648  0.000116  0.000135  0.000101  0.000117  0.00009
# 0    삼성노트북  0.000436  0.000000  0.000000  0.000000  0.000000  0.00000
# 0   게이밍노트북  0.000000  0.000000  0.000000  0.000519  0.000000  0.00000
# 0    중고노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0       삼성  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# ..     ...       ...       ...       ...       ...       ...      ...
# 0     올웨이즈  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0      울트라  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0      윈도우  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0   LG울트라북  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0       디클  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
#
#         10sc      10th      10세대  ...  롤게임용  삼성아티브노트북  삼성테블릿  번장최   현금  섬성노트북  \
# ...

# %%
tt =[]
# tt.append('label')
tt = list(lab_matrix.columns[80:][:])
tt[0] = 'label'

# %%
lab_matrix[tt]
# Out:
#      label   15zd970   15zd979   15zd980   15zd990   15zd995       15년  \
# 0      노트북  0.000204  0.000108  0.000169  0.000308  0.000208  0.000289
# 0    삼성노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   게이밍노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0    중고노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0       삼성  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ..     ...       ...       ...       ...       ...       ...       ...
# 0    넷북노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   삼성노트북5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   라이젠노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0        탭  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   삼성아티브북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#         15년형      15인치  15인치8기가램  ...  4441s  15ud70n  박음질   방수  kbmt  \
# ...

# %% [markdown]
# # Test-set 처리

# %% [markdown]
# ## test 태그 predict

# %%
lab_test['pred']=''
for i in range(len(lab_test)):
    lab_test['pred'][i] = ', '.join(find_tag(lab_test.feature.iloc[i].split(' '), lab_matrix).label)
lab_test
# Out:
#                                   feature                            label TP  \
# 0                      msi 게이밍노트북 디지털 가전   게이밍노트북,노트북,msi게이밍노트북,msi,msi노트북
# 1           14인치 hd dell 레티튜드 노트북 디지털 가전       델노트북,14인치노트북,노트북,중고노트북,DELL
# 2       ssd탑재 초경량 화면터치가능 태블릿겸 노트북 디지털 가전                     태블릿,노트북,ssd탑재
# 3                       엘지 울트라 기어 디지털 가전                            노트북,LG
# 4                    아수스 ux fl bm 디지털 가전                               노트북
# ...                                   ...                              ... ..
# 3290          dell inspiron 인텔 세대 디지털 가전       dell,dell노트북,인스피론,델인스피론,노트북
# 3291     고사양 게이밍 노트북 배그 로스트아크 gta 디지털 가전    게이밍노트북,msi,고사양노트북,배틀그라운드,로스트아크
# 3292               삼성 nt 부품용판매합니다 디지털 가전        노트북,부품용,nt500r5h,k10,삼성노트북
# 3293                     맥북 프로 gb 디지털 가전                 맥북,노트북,256GB,맥,애플
# 3294  lg노트북 울트라pc 그램 zd gx bk 팝니다 디지털 가전             LG노트북,LG그램,i7,14ZD950
#
#                                         pred
# ...

# %% [markdown]
# ## f1-score 계산

# %%
lab_test['TP'] = ''
for idx in range(len(lab_test)):
    count = 0
    for i in lab_test.label.iloc[idx].split(','):
        for j in lab_test.pred.iloc[idx].split(','):
            if i in j:
                count +=1
                break
            elif j in i:
                count +=1
                break
    lab_test['TP'][idx] = count
lab_test
# Out:
#                                   feature                            label TP  \
# 0                      msi 게이밍노트북 디지털 가전   게이밍노트북,노트북,msi게이밍노트북,msi,msi노트북  5
# 1           14인치 hd dell 레티튜드 노트북 디지털 가전       델노트북,14인치노트북,노트북,중고노트북,DELL  2
# 2       ssd탑재 초경량 화면터치가능 태블릿겸 노트북 디지털 가전                     태블릿,노트북,ssd탑재  0
# 3                       엘지 울트라 기어 디지털 가전                            노트북,LG  1
# 4                    아수스 ux fl bm 디지털 가전                               노트북  1
# ...                                   ...                              ... ..
# 3290          dell inspiron 인텔 세대 디지털 가전       dell,dell노트북,인스피론,델인스피론,노트북  2
# 3291     고사양 게이밍 노트북 배그 로스트아크 gta 디지털 가전    게이밍노트북,msi,고사양노트북,배틀그라운드,로스트아크  2
# 3292               삼성 nt 부품용판매합니다 디지털 가전        노트북,부품용,nt500r5h,k10,삼성노트북  1
# 3293                     맥북 프로 gb 디지털 가전                 맥북,노트북,256GB,맥,애플  3
# 3294  lg노트북 울트라pc 그램 zd gx bk 팝니다 디지털 가전             LG노트북,LG그램,i7,14ZD950  1
#
# ...

# %%
lab_test[['feature','label','pred','TP']]
# Out:
#                                   feature                            label  \
# 0                      msi 게이밍노트북 디지털 가전   게이밍노트북,노트북,msi게이밍노트북,msi,msi노트북
# 1           14인치 hd dell 레티튜드 노트북 디지털 가전       델노트북,14인치노트북,노트북,중고노트북,DELL
# 2       ssd탑재 초경량 화면터치가능 태블릿겸 노트북 디지털 가전                     태블릿,노트북,ssd탑재
# 3                       엘지 울트라 기어 디지털 가전                            노트북,LG
# 4                    아수스 ux fl bm 디지털 가전                               노트북
# ...                                   ...                              ...
# 3290          dell inspiron 인텔 세대 디지털 가전       dell,dell노트북,인스피론,델인스피론,노트북
# 3291     고사양 게이밍 노트북 배그 로스트아크 gta 디지털 가전    게이밍노트북,msi,고사양노트북,배틀그라운드,로스트아크
# 3292               삼성 nt 부품용판매합니다 디지털 가전        노트북,부품용,nt500r5h,k10,삼성노트북
# 3293                     맥북 프로 gb 디지털 가전                 맥북,노트북,256GB,맥,애플
# 3294  lg노트북 울트라pc 그램 zd gx bk 팝니다 디지털 가전             LG노트북,LG그램,i7,14ZD950
#
#                                         pred TP
# ...

# %%
# tp값 분포(계산 잘 됐나 확인)
lab_test.TP.value_counts()
# Out:
# 1    1191
# 2     950
# 0     551
# 3     446
# 4     109
# 5      48
# Name: TP, dtype: int64

# %%
# 전체 tag 개수 파악
full_tag = 0
for i in range(len(lab_test)):
    full_tag += len(lab_test.label.iloc[i].split(','))

tp = lab_test.TP.sum()
fn = full_tag-tp
fp = len(lab_test)*5 - tp

precision = tp/(tp+fp)
recall = tp/(tp+fn)
f1_score = round(2*(precision*recall)/(precision+recall),2)

print('precision : ',precision)
print('recall : ',recall)
print('F1_score : ',f1_score)
# Out:
# precision :  0.3098634294385432
# recall :  0.42033758748456157
# F1_score :  0.36

# %% [markdown]
# # 모델 저장

# %%
lab_matrix.to_csv('/Users/ppangppang/Desktop/ssac/Final_project/3.Recommen_model/tag_model/lab_model.csv',index=False)

# %% [markdown]
# # 실제 값 넣어서 확인해보기
# - 아래 식만 사용하면 됨

# %%
# 패키지 호출
import os
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import re


## 입력한 제목 전처리 및 태그출력
# title = [input('제목을 입력해주세요 : ')]
def find_tag(title, cat_matrix):
    test = title[0].split(' ')
    for i, j in enumerate(test):
        i = re.sub('\W+',' ', j)
    test_input = []
    for i in test:
        if i in cat_matrix.columns:
            test_input.append(i)
    test_input.append('label')
    # 해당 카테고리에 적용
    test_matrix = cat_matrix[test_input]
    test_matrix
    # 상위 top5 태그 추출
    test_matrix['target'] = 0
    for i in range(len(test_input)-1):
        test_matrix['target'] += test_matrix[test_input[i]] 
    test_matrix['target'] = test_matrix['target'] / (len(test_input)-1)
    test_matrix = test_matrix[['label','target']].sort_values(by='target', ascending=False)[:5]
    return(test_matrix)

lab_matrix = pd.read_csv('/Users/ppangppang/Desktop/ssac/Final_project/3.Recommen_model/tag_model/lab_model.csv')

# %%
title = [input('제목을 입력해주세요 : ')]
find_tag(title, lab_matrix)
# Out:
# 제목을 입력해주세요 : lg그램 17인치 중고 팝니다
#      label    target
# 0  lg그램노트북  0.092214
# 0  엘지그램노트북  0.090203
# 0    애플노트북  0.055516
# 0   15인치그램  0.051830
# 0     LG그램  0.051827

# %% [markdown]
# # 에어팟

# %% [markdown]
# ## 작업

# %%
# 카테고리 상태에 따라 cat1, cat2, cat3 미리 좀 거르기
air = total_df[1]
air = air[(air['cat1']=='디지털/가전')]
air = air[(air['cat2']=='PC/노트북') | (air['cat2']=='오디오/영상/관련기기') | (air['cat2']=='모바일') | (air['cat2']=='PC부품/저장장치')]
air = air[(air['cat3'] == '이어폰/헤드폰') | (air['cat3'] == '케이스/보호필름/액세서리') | (air['cat3'] == '아이팟/MP3/PMP') | 
          (air['cat3'] == '기타(오디오/영상/관련기기)') | (air['cat3'] == '케이블/충전기/주변기기') | (air['cat3'] == 'PC주변기기(키보드/마우스)') |
          (air['cat3'] == '소모품') | (air['cat3'] == '기타(PC/노트북)') | (air['cat3'] == '기타(모바일)')]
air
# Out:
#        product_id                      title  \
# 0       175921190           (정품)에어팟2 본체+케이스
# 1       175921152  (애플정품)에어팟2 양쪽 왼쪽유닛.오른쪽유닛
# 2       175921105       에어팟2세대 본체 S급 (2개월사용)
# 3       174518213            디즈니 에어팟 1/2 케이스
# 4       175921064              에어팟2 미개봉 새 제품
# ...           ...                        ...
# 29934   144967603                    에어팟2미개봉
# 29935   144966522                  에어팟2세대 유선
# 29936   144964523                에어팟 2세대 팝니다
# 29937   144956868                     에어팟2세대
# 29939   142267068          에어팟 1 정품 풀박 케이스포함
#
#                                   keyword    cat1         cat2           cat3  \
# 0                    애플,이어폰,에어팟2,에어팟1,케이스  디지털/가전  오디오/영상/관련기기        이어폰/헤드폰
# 1                      애플,이어폰,에어팟2,왼쪽,오른쪽  디지털/가전  오디오/영상/관련기기        이어폰/헤드폰
# 2                    애플,이어폰,에어팟2,에어팟1,케이스  디지털/가전  오디오/영상/관련기기        이어폰/헤드폰
# 3                  에어팟케이스,에어팟1케이스,에어팟2케이스  디지털/가전          모바일  케이스/보호필름/액세서리
# ...

# %%
air = location(air) # 지역정보 걸러야 할 경우만 시행
air = merge_df(air) # feature, label로 만들기
air = air[(air.label != 'nan') &(air.label != '')] # label 빈거 지우기
air.index=range(len(air))
air = proccessing(air) # 특수문자, 한글자 전처리
air
# Out:
#                                   feature                               label
# 0                   정품 에어팟 본체 케이스 디지털 가전                 애플,이어폰,에어팟2,에어팟1,케이스
# 1          애플정품 에어팟 양쪽 왼쪽유닛 오른쪽유닛 디지털 가전                   애플,이어폰,에어팟2,왼쪽,오른쪽
# 2               에어팟 세대 본체 s급 개월사용 디지털 가전                 애플,이어폰,에어팟2,에어팟1,케이스
# 3                     디즈니 에어팟 케이스 디지털 가전               에어팟케이스,에어팟1케이스,에어팟2케이스
# 4                      에어팟 미개봉 제품 디지털 가전              에어팟,에어팟2,미개봉,새제품,에어팟미개봉
# ...                                   ...                                 ...
# 19682  에어팟 세대 유선충전모델 에눌 ㄱㄴ 택배비 포함 디지털 가전                        에어팟,에어팟2세대유선충
# 19683                   에어팟 세대 유선 디지털 가전                 에어팟,에어팟프로,에어팟2세댜,헤드셋
# 19684                  에어팟 세대 팝니다 디지털 가전   에어팟,에어팟2세대정품,에어팟2세대유선충,직거래만가능,박스포함
# 19685                      에어팟 세대 디지털 가전                        에어팟,오른쪽,오른쪽유닛
# 19686             에어팟 정품 풀박 케이스포함 디지털 가전                     에어팟,에어팟정품,에어팟1급처
#
# [19687 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(air['feature'],air['label'], test_size=0.2,shuffle=True, random_state=42)

# %%
air_train = pd.DataFrame()
air_train['feature'] = X_train
air_train['label'] = y_train
air_train.index=range(len(air_train))

air_test = pd.DataFrame()
air_test['feature'] = X_test
air_test['label'] = y_test
air_test.index=range(len(air_test))

# %%
air_train.head(3)
# Out:
#                              feature                               label
# 0  정품 에어팟 세대 무선 왼쪽 오른쪽 유닛 판매 디지털 가전   에어팟,에어팟2무선,에어팟2무선유닛,에어팟2세대무선,에어팟유닛
# 1              에어팟 본체 오른쪽 유닛 디지털 가전                                 에어팟2
# 2                     에어팟 세대 디지털 가전             에어팟2세대정품,분당,용인,직거래,택배비무료

# %%
air_test.head(3)
# Out:
#                               feature                           label
# 0                   에어팟 본체 급처 디지털 가전                        에어팟,에어팟프로
# 1  최저가 프로 왼쪽 오른쪽 본체 에어팟 세대 세대 디지털 가전   에어팟,에어팟충전케이스,에어팟본체,에어팟2,에어팟오른쪽
# 2                         에어팟 디지털 가전        에어팟프로,에어팟2,에어팟,에어팟본체,에어팟3

# %%
# 모델링
air_train = split_label(air_train)
tag_list = tag(air_train)
air_matrix = make_matrix(tag_list,air_train)
air_matrix
# Out:
#   0%|          | 0/314 [00:00<?, ?it/s]
#       label      acro     actto       air   airplus    airpod   airpods  \
# 0       에어팟  0.000242  0.000119  0.000315  0.000208  0.000144  0.001810
# 0     에어팟프로  0.000000  0.000155  0.000000  0.000000  0.000318  0.002431
# 0    에어팟케이스  0.000000  0.000000  0.000328  0.000000  0.000000  0.001093
# 0      에어팟2  0.000000  0.000000  0.000000  0.000000  0.000000  0.001198
# 0    에어팟2세대  0.000000  0.000000  0.000000  0.000000  0.000000  0.001772
# ..      ...       ...       ...       ...       ...       ...       ...
# 0        맥스  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0       이어팁  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   에어팟왼쪽유닛  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0    귀여운케이스  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0    이어폰케이스  0.000000  0.000000  0.000000  0.000000  0.000000  0.034788
#
# ...

# %% [markdown]
# ## 필요없는 feature 제거

# %%
a=(air_matrix.columns.to_list())
a
# Out:
# ['label',
#  'acro',
#  'actto',
#  'air',
#  'airplus',
#  'airpod',
#  'airpods',
#  'aitw',
#  'akg',
#  'am',
#  'anc',
#  'apieceofcake',
#  'apple',
#  'april',
#  'ath',
#  'a급',
#  'a타입',
#  'back',
#  'bcs',
#  'beat',
#  'beats',
#  'belkin',
#  'best',
#  'bmw',
#  'bns',
#  'boss',
#  'bragi',
#  'bt',
#  'buds',
#  'b급',
#  'care',
#  'case',
#  'ch',
#  'charge',
#  'chipi',
#  'cn',
#  'color',
#  'cosy',
#  'cp',
#  'cx',
#  'c타입',
#  'dash',
#  'diffa',
#  'diy',
#  'dock',
#  'earin',
#  'earp',
#  'earset',
#  'elago',
#  'elite',
#  'eq',
#  'ex',
#  'fast',
#  'for',
#  'free',
#  'freedy',
#  'from_w',
#  'fw',
#  'gb',
#  'gentek',
#  'gni',
#  'green',
#  'gulikit',
#  'hbs',
#  'hd',
#  'icon',
#  'ihbt',
#  'ije',
#  'in',
#  'ininepod',
#  'iphone',
#  'iriver',
#  'jabra',
#  'jays',
#  'jbl',
#  'kakao',
#  'kh',
#  'k도금',
#  'k철가루방지',
#  'left',
#  'lf',
#  'lg',
#  'lg블루투스',
#  'lg톤프리',
#  'lg톤플러스',
#  'linner',
#  'lk',
#  'lmc케이스',
#  'mademoment',
# ...

# %%
title_list =['a급', 'a급이고', 'b급', 'b급제품', 'c이하', 'from_w', 'r유닛', 'r유닛x', 'sony헤드셋', 'ssssss급', 'sss급', 'ss급', 's급', 'tws팔아요', 'tws팔아요', 'ㄱㄱ', 'ㄱㄱ', 'ㄱㄴ', 'ㄱㄴ', 'ㄴ유선', 'ㄴ유선', 'ㅇㅇㅍㅍㄹ', 'ㅈㄴ', 'ㅍㅍ', 'ㅍㅍㅍㅍㅍㅍㅍㅍㅍㅍㅍㅍㅍ', 'ㅜㅜ', 'ㅜㅜ', 'ㅠㅠ', 'ㅠㅠㅠ', '가격', '가격낮춤', '가격낮춤', '가격내렸음', '가격내림', '가격다운', '가격변경', '가격상의', '가격상의', '가격수정', '가격올림', '가격인하', '가격인하', '가격인하합니다', '가격인하합니다', '가격인하합니다', '가격인하합니다', '가격조정가능', '가격할인', '가격할인', '가능합니다', '가능합니다', '가능해요', '가방', '가방고리', '가성비', '가성비갑', '가져가세요', '각인무료', '각인있는', '각인있는', '감성의', '감쪽같은', '갑니다', '강추', '강화유리', '같이', '개ㅍㅍ', '개가격', '개꿀매', '개남음', '개당', '개만원', '개별판매', '개별판매가능', '개보유중', '개봉만한', '개월사용', '개월사용', '개월사용풀셋', '개월사용풀셋', '개월쓴거에요', '개이상', '개판매', '갤럭시기종보유', '갤럭시워치se이상교환가능', '갤럭시워치se이상교환가능', '거래완료', '거래해요', '거의', '거의새거', '거의새거', '거의새거판매', '거의새거판매', '거의새거판매', '거의새것', '거의새것', '거의새상품', '걱정하는찰리', '검거완료', '검은색', 
              '겔스티커', '계란빵', '고급', '고급가죽에어팟케이스키링세트', '고급짐', '고리있음', '고리있음', '괜찮은', '교신및', '교신할사람', '교신합니다', '교신합니다', '교신해요', '교육할인프로모션', '교환', '교환가능', '교환가능합니다', '교환가능합니다', '교환가능합니다', '교환구함', '교환구함', '교환구합니다', '교환구합니다', '교환구합니다', '교환도', '교환바람', '교환하시분', '교환하시분', '교환하실분', '교환하실분', '교환합니다', '교환합니다', '교환합니다', '구매원합니다', '구매원합니다', '구매원해요', '구매하실분', '구매합니다', '구매합니다', '구매합니당', '구매합니당', '구매해요', '구매희망합니다', '구매희망합니다', '구미베어', '구입합니다', '구입합니다', '구함', '구합니다', '구합니다', '구합니닷', '구해봅니다', '구해요', '국내무료배송', '국내무료배송', '국내무료배송', '국내발정품', '국내산', '국내생산', '국내정발', '국내정식', '국내정품', '국내제작', '권은비', '귀멸의칼날', '급급급처', '급매', '급매물', '급속', '급처', '급처s급', '급처분', '급처분', '급처분합니다', '급처분합니다', '급처분합니다', '급처분합니다', '급처에어팟', '급처위주', '급처합니다', '급처합니다', '급처합니다', 
             '급처해요', '급처해요', '급처해욥', '급쳐', '급쳐합니다', '급쳐합니다', '급쳐합니다', '급쳐해봅니다', '급쳐해봅니다', '급쳐해봅니당', '급쳐해봅니당', '급하게', '급하게팔아봅니다ㅠㅠ', '급하게팔아봅니다ㅠㅠ', '급하게팔아봅니다ㅠㅠ', '급하게팔아봅니다ㅠㅠ', '급해요', '급해요', '급히', '기스없는', '긴급급처', '긴급처분', '긴급처분', '까지', '깔끔하고', '깨끗상태의', '깨끗합니당', '깨끗합니당', '깨끗해요', '껴보기만함', '꽃달은', '꿀단지', '꿀매', '꿀매물', '끊김오류있는', '끊김오류있는', '나눔이벤트', '나의', '남아있어요', '남았습니다', '남포동까지', '낮춤', '낱개판매', '낱개판매전문', '내고가능', '내구성좋은', '내구성좋은', '내려요', '낼까지만', '낼까지만', '넣어드려요', '네고', '네고가능', '네고가능', '네고문의', '네고문의', '네이티브유니온', '년무상수리가능', '년사용', '년사용', '년제품s급', '노랑', '노랑곰', '노랑새', '노랑이', '노을진', '다구매합니다', '다구매합니다', '다사요', '달미만', '당근', '당근정품', '당근케이스', '당근토끼', '당일', '당일발송', '당일배송', '당일배송', '당일배송전문', '당일배송전문', '당일출고', '당첨', '당한분', '당한분', '대구', '대당', '대랑', '대량있습니다', '대량있습니다', '대량할인판매', '대량할인판매', '대리구매해드립니다', '대만', '더나은', '되는', '두개같이드려요', '두개같이드려요', '두개팔아요', '두개팔아요', '드려요', '드립니다', '듣는거는', '등급', '등급', '등등', '디테일살아있는', '디테일살아있는', '딸기에어�
�유닛만', '양쪽유닛만', '양쪽이어폰만', '어제배송된거팔아요', '어제배송된거팔아요', '어제배송된거팔아요', '언박싱만', '얼마안쓴버즈프로팝니다', '얼마안쓴버즈프로팝니다', '얼마안쓴버즈프로팝니다', '없는', '없는거', '없어요ㅜㅜ', '없어요ㅜㅜ', '없어요ㅜ분실로인한', '없어요ㅜ분실로인한', '없어요ㅜ분실로인한', '없음', '에눌', '에눌o', '에눌가능', '에눌가능합니다', '에눌가능합니다', '에눌가능합니다', '에스급', '에스더러브유', '에스에스에스급', '에어팔', '에어팟s급', '에어팟삽니다', '에어팟싸게팔아용', '에어팟왼쪽유닛', '에어팟유닛', '에어팟이랑', '에어팟케이스_당일출고가능', '에어팟케이스_당일출고가능', '에어팟케이스_당일출고가능', '에어팟케이스추천', '에어팟케이스팔아요', '에어팟케이스팔아요', '에어팟판매', '에어팟팝니다', '에어팟팝니다', '에어팟프로랑', '에어팟프로무하자', '에어팟프로미개봉삽니다', '에어팟프로본체만', '에어팟프로본체삽니다', '에어팟프로본체삽니당', '에어팟프로삽니다', '에어팟프로싸게급처해요', '에어팟프로싸게급처해요', '에어팟프로왼쪽유닛', '에어팟프로유닛팝니다', '에어팟프로유닛팝니다', '에어팟프로유닛팝니다', '에어팟프로판매', '에어팟프로판매합니다', '에어팟프로판매합니다', '에어팟프로판매합니다', '에어팟프로팔아요', '에어팟프로팔아요', '에어팟프로팝니다', '에어팟프로팝니다', '여러컬러있음', '여러컬러있음', '여분', '여행가방젤리', '역대급', '연노랑', '연락주세요', '연분홍', '열쇠고리없음', '영상있음', '영상있음', '영이의', '오늘까지만', '오늘까지만', '오늘만', '오늘만이가격', '오늘만이가격', '오늘만특가', '오른유닛과', '오른쪽만', '오른쪽만잇어요', '오른쪽만있음', '오른쪽만있음', '오른쪽만있음', '오른쪽만팔아요', '오른쪽만팔아요', '오른쪽만팔아요', '오른쪽만팝니다', '오른쪽만팝니다', '오른쪽만팝니다', '오른쪽삽니다', '오른쪽없음', '오른쪽유닛', '오른쪽유닛x', '오른쪽유닛없음', '오른쪽유닛없음', '오른쪽유닛이', '오른쪽유닛이랑', '오른쪽유닛이랑', '오른쪽유닛팔아요', '오른쪽유닛팔아요', '오른쪽유닛팔아요', '오른쪽유닛팝니당', '오른쪽유닛팝니당', '오른쪽유닛팝니당', '오른쪽이랑', '오른쪽잃어버려서팝니다', '오른쪽잃어버려서팝니다', '오른쪽잃어버려서팝니다', '오른쪽판매합니다', '오른쪽판매합니다', '오른쪽판매합니다', '오른쪽팝니다', '오른쪽팝니다', '올려요', '완료', '완료된', '완전', '완전미개봉', '완전새것', '완전새것', '완전새제품', '완전쌔거', '완전쌔거', '완전이쁘다', '완전체o', '완쪽', '완투', '완투프로케이스', '외부스피커', '왼쪽만', '왼쪽만있음', '왼쪽만있음', '왼쪽만있음', '왼쪽삽니다', '왼쪽없음', '왼쪽유닛', '왼쪽유닛x', '왼쪽유닛불량', '왼쪽유닛없음', '왼쪽유닛없음', '왼쪽유닛팝니다', '왼쪽유닛팝니다', '왼쪽유닛
�박스거의새상품', '풀박스입니다', '풀박스입니당', '프로a급', '프로랑', '프로를', '프로만', '프로본체만', '프로팔아요', '프로팔아요', '프로팝니다', '프로팝니다', '피해보신분', '핀매합니다', '핀매합니다', '필요하신분', '핍니다', '하고', '하나남은거', '하드케이스팝니다', '하드케이스팝니다', '하루만', '하실분', '하얀색있어요', '하이엔드급', '하자', '하자x', '하자x생활기스o', '하자없고', '하자없습니당', '하자없습니당', '하자없음', '하자없음', '하자있는', '하자있는', '하자있는', '하자있음', '하자있음', '하자있음', '하자제품',
             '한개가격', '한정판', '한쪽만', '한쪽씩팝니다', '한쪽씩팝니다', '한쪽없는것도삼', '할부로', '할수', '할인', '할인중', '할인쿠폰', '합니다', '합니다', '합니당', '합니당', '해드려요', '해외배송', '핸드폰가방과', '헤드', '헤드셋', '헤드폰', '헤드폰플러그', '현금이벤트진행중', '협의', '호랑이', '호빵맨', '호환만', '혹은', '환영', '환자의', '회이하', '후기많아요', '후기좋은', '후기좋은', '후기천개이상'

            ]

# %%
a = list(set(a)-set(title_list))
a.sort()
print(a)
print(len(a))
# Out:
# ['aaa', 'acro', 'actto', 'air', 'airdots', 'airp', 'airplus', 'airpod', 'airpodpro', 'airpods', 'airpots', 'aitw', 'akg', 'am', 'anc', 'anker', 'apieceofcake', 'apple', 'april', 'as불가능', 'as전문점', 'ath', 'atwo', 'a타입', 'baby', 'back', 'banada', 'basic', 'battery', 'bcs', 'beat', 'beats', 'beer', 'belkin', 'best', 'bmw', 'bns', 'bose', 'boss', 'box', 'bragi', 'britz', 'brother', 'brunch', 'bt', 'bts', 'buds', 'care', 'case', 'casetify', 'casetry', 'ch', 'charge', 'chipi', 'chuck', 'club', 'cn', 'coco', 'color', 'cosy', 'cp', 'cx', 'c타입', 'c타입충전기', 'c타입케이블', 'dadamong', 'dash', 'dhl', 'diffa', 'diy', 'dock', 'domi', 'dr무선이어폰', 'ds', 'duotone', 'ea', 'earbuds', 'earin', 'earp', 'earset', 'eco', 'eer', 'elago', 'elite', 'eq', 'ex', 'fast', 'feat', 'fit', 'for', 'free', 'freedy', 'fw', 'gb', 'gear', 'gentek', 'gmpodstws', 'gni', 'green', 'gulikit', 'hbs', 'hd', 'heg', 'hi', 'iab', 'icon', 'ideal', 'ihbt', 'ije', 'in', 'ininepod', 'iphone', 'iriver', 'itw', 'jabra', 'jays', 'jbl', 'kakao', 
# ...

# %%
temp = []
dum = ['팜','팝','니다','급','가격','뜨끈','인츠','_','배송','들고','새거','새것','노북','수리','ㅜ','ㅡ',
       '이번','까지','좋고','헤드','명품','고가','저가','질러','짭','세요','구함','교환','좋아','일주일','잘','사용','려요',
       '좋은','할때','볼때','꿀','해요','속도','라요','아요','을','는','은','를','또는','이상','이하','추천','사요','의','랑','됫',
       '됬','됐','됏','무료','마우스','키보드','스피커','사용','쓴','네고','환영','하자','없음','있음','good','할','가성','매우','등',
       '아이폰','갤럭사','만','으로','멕','애눌','에눌','이벤트','인기','서울','익산','전주','대구','인천','진짜','즉시','증정','지금',
       '출장','남음','낮춤','넷플','보증','갤럭스','겔','좋음','나쁨','택배','합니','당','보건','업글','동묘','거북','ㅜ','가방','떨이',
       '분','ㄱㄱ','ㅠ','ㅍ','볍워','있','저렴','완','이쁨','제거','국내','하고','갓','강남','구미','간편','강추','같이','ㄱ','ㄴ','ㄷ',
       '빵','욤','어서','아님','요가','인지','이쁜','및','인차','아산','논현','유','팔','잃','인티','인하','판','최강','탈거','배터리',
       '쌔','쎄'
       ]
for i in a:
    for j in dum:
        if j in i:
            temp.append(i)
print(temp)
# Out:
# ['겔럭시', '겔럭시버즈']

# %%
# 필요없는 정보 담아서 지우기
# title_list
for i in title_list:
    air_train['feature'] = air_train['feature'].str.replace(i, '')
air_train
# Out:
#                                              feature  \
# 0                      정품 에어팟 세대 무선 왼쪽 오른쪽   디지털 가전
# 1                                에어팟 본체 오른쪽  디지털 가전
# 2                                     에어팟 세대 디지털 가전
# 3                                 에어팟 프로 본체  디지털 가전
# 4                          에어팟프로케이스 키링세트 새제품 디지털 가전
# ...                                              ...
# 15744                       에어팟 프로  피트니스 팩토리 디지털 가전
# 15745                              에어팟 충전 모델 디지털 가전
# 15746  새제품 새상품 에어팟 에어팟 실리콘 컬러 무지 케이스 키링고리 구멍 디지털 가전
# 15747                                    에어팟 디지털 가전
# 15748                            대리석 에어팟 케이스 디지털 가전
#
#                                     label       label1    label2    label3  \
# 0      에어팟,에어팟2무선,에어팟2무선유닛,에어팟2세대무선,에어팟유닛       에어팟2무선  에어팟2무선유닛  에어팟2세대무선
# 1                                    에어팟2            0         0         0
# 2                에어팟2세대정품,분당,용인,직거래,택배비무료           분당        용인       직거래
# ...

# %% [markdown]
# ## 모델 재생성

# %%
air_matrix = make_matrix(tag_list,air_train)
air_matrix
# Out:
#   0%|          | 0/314 [00:00<?, ?it/s]
#       label      acro     actto       air   airplus    airpod   airpods  \
# 0       에어팟  0.000242  0.000125  0.000315  0.000208  0.000169  0.001930
# 0     에어팟프로  0.000000  0.000164  0.000000  0.000000  0.000318  0.002576
# 0    에어팟케이스  0.000000  0.000000  0.000328  0.000000  0.000000  0.001129
# 0      에어팟2  0.000000  0.000000  0.000000  0.000000  0.000000  0.001250
# 0    에어팟2세대  0.000000  0.000000  0.000000  0.000000  0.000000  0.001781
# ..      ...       ...       ...       ...       ...       ...       ...
# 0        맥스  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0       이어팁  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   에어팟왼쪽유닛  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0    귀여운케이스  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0    이어폰케이스  0.000000  0.000000  0.000000  0.000000  0.000000  0.034788
#
# ...

# %% [markdown]
# ## f1-score

# %%
air_test['pred']=''
for i in range(len(air_test)):
    air_test['pred'][i] = ', '.join(find_tag(air_test.feature.iloc[i].split(' '), air_matrix).label)
air_test
# Out:
#                                  feature  \
# 0                      에어팟 본체 급처 디지털 가전
# 1     최저가 프로 왼쪽 오른쪽 본체 에어팟 세대 세대 디지털 가전
# 2                            에어팟 디지털 가전
# 3                      에어팟 프로 박스 디지털 가전
# 4         정품 에어팟 세대 왼쪽 오른쪽 유닛 판매 디지털 가전
# ...                                  ...
# 3933                         에어팟 디지털 가전
# 3934                에어팟 케이스 시나모롤 디지털 가전
# 3935      정품 에어팟 세대 왼쪽 오른쪽 유닛 판매 디지털 가전
# 3936            에어팟 프로 상태 좋음 교신x 디지털 가전
# 3937                      에어팟 프로 디지털 가전
#
#                                          label  \
# 0                                    에어팟,에어팟프로
# 1               에어팟,에어팟충전케이스,에어팟본체,에어팟2,에어팟오른쪽
# 2                    에어팟프로,에어팟2,에어팟,에어팟본체,에어팟3
# 3                                    에어팟,에어팟프로
# 4           에어팟2세대유닛,에어팟2유닛,에어팟2왼쪽,에어팟2오른쪽,에어팟
# ...                                        ...
# 3933                                  에어팟2,에어팟
# 3934               에어팟케이스,에어팟케이스판매,에어팟,시나모롤,키링
# ...

# %%
air_test['TP'] = ''
for idx in range(len(air_test)):
    count = 0
    for i in air_test.label.iloc[idx].split(','):
        for j in air_test.pred.iloc[idx].split(','):
            if i in j:
                count +=1
                break
            elif j in i:
                count +=1
                break
    air_test['TP'][idx] = count
air_test
# Out:
#                                  feature  \
# 0                      에어팟 본체 급처 디지털 가전
# 1     최저가 프로 왼쪽 오른쪽 본체 에어팟 세대 세대 디지털 가전
# 2                            에어팟 디지털 가전
# 3                      에어팟 프로 박스 디지털 가전
# 4         정품 에어팟 세대 왼쪽 오른쪽 유닛 판매 디지털 가전
# ...                                  ...
# 3933                         에어팟 디지털 가전
# 3934                에어팟 케이스 시나모롤 디지털 가전
# 3935      정품 에어팟 세대 왼쪽 오른쪽 유닛 판매 디지털 가전
# 3936            에어팟 프로 상태 좋음 교신x 디지털 가전
# 3937                      에어팟 프로 디지털 가전
#
#                                          label  \
# 0                                    에어팟,에어팟프로
# 1               에어팟,에어팟충전케이스,에어팟본체,에어팟2,에어팟오른쪽
# 2                    에어팟프로,에어팟2,에어팟,에어팟본체,에어팟3
# 3                                    에어팟,에어팟프로
# 4           에어팟2세대유닛,에어팟2유닛,에어팟2왼쪽,에어팟2오른쪽,에어팟
# ...                                        ...
# 3933                                  에어팟2,에어팟
# 3934               에어팟케이스,에어팟케이스판매,에어팟,시나모롤,키링
# ...

# %%
# tp값 분포(계산 잘 됐나 확인)
air_test.TP.value_counts()
# Out:
# 1    2156
# 0     833
# 2     585
# 3     226
# 4      98
# 5      40
# Name: TP, dtype: int64

# %%
# 전체 tag 개수 파악
full_tag = 0
for i in range(len(air_test)):
    full_tag += len(air_test.label.iloc[i].split(','))

tp = air_test.TP.sum()
fn = full_tag-tp
fp = len(air_test)*5 - tp

precision = tp/(tp+fp)
recall = tp/(tp+fn)
f1_score = round(2*(precision*recall)/(precision+recall),2)

print('precision : ',precision)
print('recall : ',recall)
print('F1_score : ',f1_score)
# Out:
# precision :  0.23341797866937533
# recall :  0.3428059968673081
# F1_score :  0.28

# %%
air_matrix.to_csv('/Users/ppangppang/Desktop/ssac/Final_project/3.Recommen_model/tag_model/air_model.csv',index=False)

# %% [markdown]
# # 구현

# %%
# 패키지 호출
import os
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import re


## 입력한 제목 전처리 및 태그출력
# title = [input('제목을 입력해주세요 : ')]
def find_tag(title, cat_matrix):
    test = title[0].split(' ')
    for i, j in enumerate(test):
        i = re.sub('\W+',' ', j)
    test_input = []
    for i in test:
        if i in cat_matrix.columns:
            test_input.append(i)
    test_input.append('label')
    # 해당 카테고리에 적용
    test_matrix = cat_matrix[test_input]
    test_matrix
    # 상위 top5 태그 추출
    test_matrix['target'] = 0
    for i in range(len(test_input)-1):
        test_matrix['target'] += test_matrix[test_input[i]] 
    test_matrix['target'] = test_matrix['target'] / (len(test_input)-1)
    test_matrix = test_matrix[['label','target']].sort_values(by='target', ascending=False)[:5]
    return(test_matrix)

air_matrix = pd.read_csv('/Users/ppangppang/Desktop/ssac/Final_project/3.Recommen_model/tag_model/air_model.csv')

# %%
title = [input('제목을 입력해주세요 : ')]
find_tag(title, air_matrix)
# Out:
# 제목을 입력해주세요 : 갤럭시 버즈 쓰던거 판매
#      label    target
# 77   버즈에어팟  0.166667
# 143    버즈2  0.143756
# 101  버즈플러스  0.125327
# 69    버즈프로  0.089755
# 61   버즈라이브  0.087002

# %% [markdown]
# ## 성능비교 Okt

# %% [markdown]
# ### okt nouns

# %%
from konlpy.tag import Okt


# 이중 리스트를 하나로
def one_list(nouns):
  test = []
  for i in range(len(nouns)):
      ## 한글자 처리
      for k in range(len(nouns[i])):
        if len(nouns[i][k]) == 1:
          nouns[i][k] = ''

      temp=''
      for j in range(len(nouns[i])):
        if j < len(nouns[i])-1:
          temp += nouns[i][j] + ' '
        else:
          temp = temp + nouns[i][j]
      test.append(temp)
  info = test
  return(info)  

################################################################################

def proccessed(cat):
  info=[]
  nouns=[]
  # tokenizer = Mecab()
  tokenizer = Okt()

  for i in range(len(cat)):
      info.append(cat['feature'][i]) # 데이터 프레임 feature를 list로
      nouns.append(tokenizer.nouns(info[i])) # feature를 각각 형태소 분리
      # nouns.append(tokenizer.morphs(info[i])) # feature를 각각 형태소 분리
  
  # 이중 리스트로 되어 있는 텍스트를 하나의 리스트로 변형    
  info = one_list(nouns)

  # 특수문자, 불용어 제거
  for i in range(len(info)):
    info[i] = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", info[i])
    
#   # stop_word 지정 및 적용
#   stop_words = "은 는 이 가 이하 이상 차 형 용품 용 ㅍ ㅍㅍ ㅠ ㅠㅠ ㅜ ㅜㅜ ㅊ ㅊㅊ ㄸ ㅎㅎ 0 00 0003" 
#   stop_words = stop_words.split(' ') 

#   for i in range(len(info)):
#     word_tokens = word_tokenize(info[i]) 

#     result = [] 
#     for w in word_tokens: 
#       if w not in stop_words: 
#         result.append(w)
#     info[i] = result

  # 이중 리스트로 되어 있는 텍스트를 하나의 리스트로 변형
  info = one_list(nouns)
  return(info)


  # 입력정보 전처리
def proccessed_input(text):
  info=text

  # feature를 각각 형태소 분리
  # tokenizer = Mecab()
  tokenizer = Okt()
  nouns=[]
  for line in info:
      nouns.append(tokenizer.nouns(line))
      # nouns.append(tokenizer.morphs(line))
  nouns

  info = one_list(nouns)

  for i in range(len(info)):
    info[i] = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", info[i])

  # stop_word 지정 및 적용
  stop_words = "은 는 이 가 이하 이상 차 형 용품 용 ㅍ ㅍㅍ ㅠ ㅠㅠ ㅜ ㅜㅜ ㅊ ㅊㅊ ㄸ ㅎㅎ" 
  stop_words = stop_words.split(' ') 

  for i in range(len(info)):
    word_tokens = word_tokenize(info[i]) 

    result = [] 
    for w in word_tokens: 
      if w not in stop_words: 
        result.append(w)
    info[i] = result

  # 이중 리스트로 되어 있는 텍스트를 하나의 리스트로 변형
  info = one_list(nouns)
  return(info)

# %%
# 카테고리 상태에 따라 cat1, cat2, cat3 미리 좀 거르기
lab = total_df[0]
lab = lab[(lab['cat1']=='디지털/가전')]
lab = lab[(lab['cat2']=='PC/노트북')]
lab = lab[(lab['cat3']=='노트북/넷북') | (lab['cat3']=='기타(PC/노트북)') | (lab['cat3']=='0')]
lab
# Out:
#        product_id                                     title  \
# 2       175915881  삼성 실버 i5 6세대 램 8G SSD 256G 1.29kg 새배터리장착
# 3       175708161               삼성 갤럭시북 플렉스 알파 노트북 스크린 터치 펜
# 6       175915630                   고사양 msi 게이밍 노트북 gtx1650
# 9       175895274              LG 울트라북 ZD360/가벼워 휴대성 좋은 노트북
# 10      175915560          삼성최저가슬림형!!!,노트북(13인치)슬림형노트북 팝니다.
# ...           ...                                       ...
# 29935   168648094                      HP envy13 i5 6세대 노트북
# 29936   168842625                               *2021 그램17*
# 29937   169796266        삼성노트북 NT270E5U 15.6인치 I3-3120m 의정부
# 29938   169137815                     게이밍 노트북 프레데터 헬리오스 500
# 29939   169415756           삼성노트북  I5-3337U 13인치 8G SSD250G
#
#                         keyword    cat1    cat2        cat3  view  \
# 2                     삼성노트북,노트북  디지털/가전  PC/노트북      노트북/넷북     6
# 3          삼성노트북,갤럭시북플,플렉스,펜,이온  디지털/가전  PC/노트북      노트북/넷북    34
# ...

# %%
lab = location(lab) # 지역정보 걸러야 할 경우만 시행
lab = merge_df(lab) # feature, label로 만들기
lab = lab[(lab.label != 'nan') &(lab.label != '')] # label 빈거 지우기
lab.index=range(len(lab))

pro_lab = proccessed(lab)
lab['feature'] = pro_lab
lab
# Out:
#                                  feature                                label
# 0                  삼성 실버 세대  배터리  디지털 가전                            삼성노트북,노트북
# 1      삼성 갤럭시  플렉스 알파 노트북 스크린 터치  디지털 가전                 삼성노트북,갤럭시북플,플렉스,펜,이온
# 2                      사양 게이  노트북 디지털 가전             게이밍,노트북,로스트아크,gtx1650,게임
# 3                     울트라북 휴대 노트북 디지털 가전                           울트라북,ZD360
# 4             최저 슬림 노트북 인치 슬림 노트북 디지털 가전              삼성,삼성노트북,노트북,중고노트북,13인치
# ...                                  ...                                  ...
# 16467             미개  갤럭시 노트북  판매 디지털 가전                노트북,Book,북고,galaxy,삼성
# 16468              게이  노트북 배그  가능 디지털 가전                노트북,배그,로아,게이밍노트북,ASUS
# 16469                   노트북 제피 러스 디지털 가전  제피러스g15,rog노트북,asus노트북,게이밍노트북,대구노트북
# 16470                          그램 디지털 가전                             노트북,lg그램
# 16471           게이  노트북 프레데터 헬리오스 디지털 가전                      게이밍,게이밍노트북,1070
#
# [16472 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(lab['feature'],lab['label'], test_size=0.2,shuffle=True, random_state=42)

lab_train = pd.DataFrame()
lab_train['feature'] = X_train
lab_train['label'] = y_train
lab_train.index=range(len(lab_train))

lab_test = pd.DataFrame()
lab_test['feature'] = X_test
lab_test['label'] = y_test
lab_test.index=range(len(lab_test))

# %%
# 모델링
lab_train = split_label(lab_train)
tag_list = tag(lab_train)
lab_matrix = make_matrix(tag_list,lab_train)
lab_matrix
# Out:
#   0%|          | 0/322 [00:00<?, ?it/s]
#      label        가격        가구        가능        가로        가방        가성  \
# 0      노트북  0.008264  0.000230  0.006336  0.000279  0.001742  0.003395
# 0    삼성노트북  0.005231  0.000551  0.008288  0.000000  0.000545  0.007068
# 0   게이밍노트북  0.009812  0.000000  0.012540  0.000000  0.000394  0.005555
# 0    중고노트북  0.002409  0.000000  0.012803  0.000000  0.001081  0.010797
# 0       삼성  0.008658  0.000000  0.009512  0.000000  0.003699  0.006659
# ..     ...       ...       ...       ...       ...       ...       ...
# 0     올웨이즈  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0      울트라  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0      윈도우  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0   LG울트라북  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0       디클  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
lab_test['pred']=''
for i in range(len(lab_test)):
    lab_test['pred'][i] = ', '.join(find_tag(lab_test.feature.iloc[i].split(' '), lab_matrix).label)
lab_test
# Out:
#                               feature                            label  \
# 0                      게이  노트북 디지털 가전  게이밍노트북,노트북,msi게이밍노트북,msi,msi노트북
# 1                 인치  레티튜드 노트북 디지털 가전      델노트북,14인치노트북,노트북,중고노트북,DELL
# 2     탑재  경량 화면 터치 가능 태블릿  노트북 디지털 가전                    태블릿,노트북,ssd탑재
# 3                    엘지 울트라 기어 디지털 가전                           노트북,LG
# 4                          아수스 디지털 가전                              노트북
# ...                               ...                              ...
# 3290                     인텔 세대 디지털 가전      dell,dell노트북,인스피론,델인스피론,노트북
# 3291      사양 게이  노트북 배그 로스트 아크 디지털 가전   게이밍노트북,msi,고사양노트북,배틀그라운드,로스트아크
# 3292                 삼성 부품  판매 디지털 가전       노트북,부품용,nt500r5h,k10,삼성노트북
# 3293                     맥북 프로 디지털 가전                맥북,노트북,256GB,맥,애플
# 3294                노트북 울트라 그램 디지털 가전            LG노트북,LG그램,i7,14ZD950
#
#                                        pred
# 0     1650, ASUS노트북, msi게이밍노트북, msi노트북, 리전5
# ...

# %%
lab_test['TP'] = ''
for idx in range(len(lab_test)):
    count = 0
    for i in lab_test.label.iloc[idx].split(','):
        for j in lab_test.pred.iloc[idx].split(','):
            if i in j:
                count +=1
                break
            elif j in i:
                count +=1
                break
    lab_test['TP'][idx] = count
lab_test
# Out:
#                               feature                            label  \
# 0                      게이  노트북 디지털 가전  게이밍노트북,노트북,msi게이밍노트북,msi,msi노트북
# 1                 인치  레티튜드 노트북 디지털 가전      델노트북,14인치노트북,노트북,중고노트북,DELL
# 2     탑재  경량 화면 터치 가능 태블릿  노트북 디지털 가전                    태블릿,노트북,ssd탑재
# 3                    엘지 울트라 기어 디지털 가전                           노트북,LG
# 4                          아수스 디지털 가전                              노트북
# ...                               ...                              ...
# 3290                     인텔 세대 디지털 가전      dell,dell노트북,인스피론,델인스피론,노트북
# 3291      사양 게이  노트북 배그 로스트 아크 디지털 가전   게이밍노트북,msi,고사양노트북,배틀그라운드,로스트아크
# 3292                 삼성 부품  판매 디지털 가전       노트북,부품용,nt500r5h,k10,삼성노트북
# 3293                     맥북 프로 디지털 가전                맥북,노트북,256GB,맥,애플
# 3294                노트북 울트라 그램 디지털 가전            LG노트북,LG그램,i7,14ZD950
#
#                                        pred TP
# 0     1650, ASUS노트북, msi게이밍노트북, msi노트북, 리전5  5
# ...

# %%
# 전체 tag 개수 파악
full_tag = 0
for i in range(len(lab_test)):
    full_tag += len(lab_test.label.iloc[i].split(','))

tp = lab_test.TP.sum()
fn = full_tag-tp
fp = len(lab_test)*5 - tp

precision = tp/(tp+fp)
recall = tp/(tp+fn)
f1_score = round(2*(precision*recall)/(precision+recall),2)

print('precision : ',precision)
print('recall : ',recall)
print('F1_score : ',f1_score)
# Out:
# precision :  0.29748103186646435
# recall :  0.4035405516673528
# F1_score :  0.34

# %%
# lg그램 17인치 중고 팝니다
title = [input('제목을 입력해주세요 : ')]
tag = find_tag(title, cat_matrix = lab_matrix)
tag
# Out:
# 제목을 입력해주세요 : lg그램 17인치 중고 팝니다
#      label    target
# 0    hp프로북  0.331209
# 0  레노버씽크패드  0.288703
# 0  삼성중고노트북  0.244336
# 0      프로북  0.213836
# 0    애플노트북  0.191692

# %% [markdown]
# ### okt 형태소

# %%
from konlpy.tag import Okt


# 이중 리스트를 하나로
def one_list(nouns):
  test = []
  for i in range(len(nouns)):
      ## 한글자 처리
      for k in range(len(nouns[i])):
        if len(nouns[i][k]) == 1:
          nouns[i][k] = ''

      temp=''
      for j in range(len(nouns[i])):
        if j < len(nouns[i])-1:
          temp += nouns[i][j] + ' '
        else:
          temp = temp + nouns[i][j]
      test.append(temp)
  info = test
  return(info)  

################################################################################

def proccessed(cat):
  info=[]
  nouns=[]
  # tokenizer = Mecab()
  tokenizer = Okt()

  for i in range(len(cat)):
      info.append(cat['feature'][i]) # 데이터 프레임 feature를 list로
#       nouns.append(tokenizer.nouns(info[i])) # feature를 각각 형태소 분리
      nouns.append(tokenizer.morphs(info[i])) # feature를 각각 형태소 분리
  
  # 이중 리스트로 되어 있는 텍스트를 하나의 리스트로 변형    
  info = one_list(nouns)

  # 특수문자, 불용어 제거
  for i in range(len(info)):
    info[i] = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", info[i])
    
#   # stop_word 지정 및 적용
#   stop_words = "은 는 이 가 이하 이상 차 형 용품 용 ㅍ ㅍㅍ ㅠ ㅠㅠ ㅜ ㅜㅜ ㅊ ㅊㅊ ㄸ ㅎㅎ 0 00 0003" 
#   stop_words = stop_words.split(' ') 

#   for i in range(len(info)):
#     word_tokens = word_tokenize(info[i]) 

#     result = [] 
#     for w in word_tokens: 
#       if w not in stop_words: 
#         result.append(w)
#     info[i] = result

  # 이중 리스트로 되어 있는 텍스트를 하나의 리스트로 변형
  info = one_list(nouns)
  return(info)


  # 입력정보 전처리
def proccessed_input(text):
  info=text

  # feature를 각각 형태소 분리
  # tokenizer = Mecab()
  tokenizer = Okt()
  nouns=[]
  for line in info:
#       nouns.append(tokenizer.nouns(line))
      nouns.append(tokenizer.morphs(line))
  nouns

  info = one_list(nouns)

  for i in range(len(info)):
    info[i] = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", info[i])

  # stop_word 지정 및 적용
  stop_words = "은 는 이 가 이하 이상 차 형 용품 용 ㅍ ㅍㅍ ㅠ ㅠㅠ ㅜ ㅜㅜ ㅊ ㅊㅊ ㄸ ㅎㅎ" 
  stop_words = stop_words.split(' ') 

  for i in range(len(info)):
    word_tokens = word_tokenize(info[i]) 

    result = [] 
    for w in word_tokens: 
      if w not in stop_words: 
        result.append(w)
    info[i] = result

  # 이중 리스트로 되어 있는 텍스트를 하나의 리스트로 변형
  info = one_list(nouns)
  return(info)

def tag(cat):
  test = list(cat['label'])
  label_unique=''
  for i in range(len(test)):
    try : 
      label_unique += test[i]
    except : 
      pass
  label_unique = label_unique.split(',')
  label_unique = [v for v in label_unique if v]
  
  df = pd.DataFrame({'label_unique':label_unique, 'count':0}).groupby(['label_unique']).count().reset_index()
  df = df[df['count']>10].sort_values(by='count',ascending=False).reset_index()[['label_unique','count']]
  top = list(df['label_unique'])

  return(top)

# %%
# 카테고리 상태에 따라 cat1, cat2, cat3 미리 좀 거르기
lab = total_df[0]
lab = lab[(lab['cat1']=='디지털/가전')]
lab = lab[(lab['cat2']=='PC/노트북')]
lab = lab[(lab['cat3']=='노트북/넷북') | (lab['cat3']=='기타(PC/노트북)') | (lab['cat3']=='0')]

lab = location(lab) # 지역정보 걸러야 할 경우만 시행
lab = merge_df(lab) # feature, label로 만들기
lab = lab[(lab.label != 'nan') &(lab.label != '')] # label 빈거 지우기
lab.index=range(len(lab))

pro_lab = proccessed(lab)
lab['feature'] = pro_lab
lab
# Out:
#                                                feature  \
# 0       삼성 실버    세대    SSD 256  1.29 kg  배터리   디지털  가전
# 1                   삼성 갤럭시  플렉스 알파 노트북 스크린 터치  디지털  가전
# 2                      사양 msi 게이  노트북 gtx 1650 디지털  가전
# 3               LG 울트라북 ZD 360  가벼워 휴대  좋은 노트북 디지털  가전
# 4        최저  슬림  !!!, 노트북  13 인치  슬림  노트북 팝니다  디지털  가전
# ...                                                ...
# 16467                  미개   갤럭시 노트북  Go 판매 합니다 디지털  가전
# 16468                  ASUS 게이  노트북  배그    가능  디지털  가전
# 16469              노트북 asus rog 제피 러스  15 3060 디지털  가전
# 16470                              2021 그램 17  디지털  가전
# 16471                    게이  노트북 프레데터 헬리오스 500 디지털  가전
#
#                                      label
# 0                                삼성노트북,노트북
# 1                     삼성노트북,갤럭시북플,플렉스,펜,이온
# 2                 게이밍,노트북,로스트아크,gtx1650,게임
# 3                               울트라북,ZD360
# 4                  삼성,삼성노트북,노트북,중고노트북,13인치
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(lab['feature'],lab['label'], test_size=0.2,shuffle=True, random_state=42)

lab_train = pd.DataFrame()
lab_train['feature'] = X_train
lab_train['label'] = y_train
lab_train.index=range(len(lab_train))

lab_test = pd.DataFrame()
lab_test['feature'] = X_test
lab_test['label'] = y_test
lab_test.index=range(len(lab_test))

# %%
# 모델링
lab_train = split_label(lab_train)
tag_list = tag(lab_train)
lab_matrix = make_matrix(tag_list,lab_train)
lab_matrix
# Out:
#   0%|          | 0/322 [00:00<?, ?it/s]
#      label        00       000      000원       001       002      003  \
# 0      노트북  0.000087  0.000068  0.000074  0.000514  0.000212  0.00008
# 0    삼성노트북  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0   게이밍노트북  0.000000  0.000000  0.000000  0.001130  0.000000  0.00000
# 0    중고노트북  0.000000  0.000000  0.001031  0.000000  0.000000  0.00000
# 0       삼성  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# ..     ...       ...       ...       ...       ...       ...      ...
# 0     올웨이즈  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0      울트라  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0      윈도우  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0   LG울트라북  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 0       디클  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
#
#         0038       004      0047  ...   타워   한국  6000  2133  하이닉스   kl   번장  \
# ...

# %%
lab_test['pred']=''
for i in range(len(lab_test)):
    lab_test['pred'][i] = ', '.join(find_tag(lab_test.feature.iloc[i].split(' '), lab_matrix).label)
lab_test
# Out:
#                                                 feature  \
# 0                                   msi 게이  노트북 디지털  가전
# 1                      14 인치  HD  DELL 레티튜드 노트북 디지털  가전
# 2                  SSD 탑재  경량 화면 터치 가능 태블릿  노트북 디지털  가전
# 3                             엘지 울트라 기어 17  790 디지털  가전
# 4                        아수스 UX 481 FL  BM 063  디지털  가전
# ...                                                 ...
# 3290           DELL Inspiron 15 5510 인텔 11 세대   디지털  가전
# 3291              사양 게이  노트북  배그  로스트 아크  gta   디지털  가전
# 3292                삼성 nt 500     10 부품  판매 합니다 디지털  가전
# 3293                               맥북 프로 256 GB 디지털  가전
# 3294  LG 노트북 울트라 PC 그램    14 ZD 950  GX  BK  팝니다  디지...
#
#                                 label                                     pred
# 0     게이밍노트북,노트북,msi게이밍노트북,msi,msi노트북      msi게이밍노트북, msi노트북, MSI, 1660ti, msi
# 1         델노트북,14인치노트북,노트북,중고노트북,DELL        lg그램14, LG울트라북, 디클, 14인치노트북, 14인치
# ...

# %%
lab_test['TP'] = ''
for idx in range(len(lab_test)):
    count = 0
    for i in lab_test.label.iloc[idx].split(','):
        for j in lab_test.pred.iloc[idx].split(','):
            if i in j:
                count +=1
                break
            elif j in i:
                count +=1
                break
    lab_test['TP'][idx] = count

# 전체 tag 개수 파악
full_tag = 0
for i in range(len(lab_test)):
    full_tag += len(lab_test.label.iloc[i].split(','))

tp = lab_test.TP.sum()
fn = full_tag-tp
fp = len(lab_test)*5 - tp

precision = tp/(tp+fp)
recall = tp/(tp+fn)
f1_score = round(2*(precision*recall)/(precision+recall),2)

print('precision : ',precision)
print('recall : ',recall)
print('F1_score : ',f1_score)
# Out:
# precision :  0.3239453717754173
# recall :  0.439440098806093
# F1_score :  0.37

# %%
# lg그램 17인치 중고 팝니다
title = [input('제목을 입력해주세요 : ')]
tag = find_tag(title, cat_matrix = lab_matrix)
tag
# Out:
# 제목을 입력해주세요 : lg그램 17인치 중고 팝니다
#      label    target
# 0   SSD노트북  0.105829
# 0    한성컴퓨터  0.098296
# 0    hp프로북  0.090866
# 0  레노버씽크패드  0.089964
# 0  삼성중고노트북  0.085249
