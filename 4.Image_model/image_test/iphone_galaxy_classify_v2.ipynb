# %%
from glob import glob

# %%
train_app_list = glob('./test/train_raw/app/*')

# %%
train_app_list
# Out:
# ['./test/train_raw/app\\app (1).jpg',
#  './test/train_raw/app\\app (10).jpg',
#  './test/train_raw/app\\app (100).jpg',
#  './test/train_raw/app\\app (1000).jpg',
#  './test/train_raw/app\\app (10000).jpg',
#  './test/train_raw/app\\app (1001).jpg',
#  './test/train_raw/app\\app (1002).jpg',
#  './test/train_raw/app\\app (1003).jpg',
#  './test/train_raw/app\\app (1004).jpg',
#  './test/train_raw/app\\app (1005).jpg',
#  './test/train_raw/app\\app (1006).jpg',
#  './test/train_raw/app\\app (1007).jpg',
#  './test/train_raw/app\\app (1008).jpg',
#  './test/train_raw/app\\app (1009).jpg',
#  './test/train_raw/app\\app (101).jpg',
#  './test/train_raw/app\\app (1010).jpg',
#  './test/train_raw/app\\app (1011).jpg',
#  './test/train_raw/app\\app (1012).jpg',
#  './test/train_raw/app\\app (1013).jpg',
#  './test/train_raw/app\\app (1014).jpg',
#  './test/train_raw/app\\app (1015).jpg',
#  './test/train_raw/app\\app (1016).jpg',
#  './test/train_raw/app\\app (1017).jpg',
#  './test/train_raw/app\\app (1018).jpg',
#  './test/train_raw/app\\app (1019).jpg',
#  './test/train_raw/app\\app (102).jpg',
#  './test/train_raw/app\\app (1020).jpg',
#  './test/train_raw/app\\app (1021).jpg',
#  './test/train_raw/app\\app (1022).jpg',
#  './test/train_raw/app\\app (1023).jpg',
#  './test/train_raw/app\\app (1024).jpg',
#  './test/train_raw/app\\app (1025).jpg',
#  './test/train_raw/app\\app (1026).jpg',
#  './test/train_raw/app\\app (1027).jpg',
#  './test/train_raw/app\\app (1028).jpg',
#  './test/train_raw/app\\app (1029).jpg',
#  './test/train_raw/app\\app (103).jpg',
#  './test/train_raw/app\\app (1030).jpg',
#  './test/train_raw/app\\app (1031).jpg',
#  './test/train_raw/app\\app (1032).jpg',
#  './test/train_raw/app\\app (1033).jpg',
#  './test/train_raw/app\\app (1034).jpg',
#  './test/train_raw/app\\app (1035).jpg',
#  './test/train_raw/app\\app (1036).jpg',
#  './test/train_raw/app\\app (1037).jpg',
#  './test/train_raw/app\\app (1038).jpg',
#  './test/train_raw/app\\app (1039).jpg',
#  './test/train_raw/app\\app (104).jpg',
#  './test/train_raw/app\\app (1040).jpg',
#  './test/train_raw/app\\app (1041).jpg',
#  './test/train_raw/app\\app (1042).jpg',
#  './test/train_raw/app\\app (1043).jpg',
#  './test/train_raw/app\\app (1044).jpg',
#  './test/train_raw/app\\app (1045).jpg',
#  './test/train_raw/app\\app (1046).jpg',
#  './test/train_raw/app\\app (1047).jpg',
#  './test/train_raw/app\\app (1048).jpg',
#  './test/train_raw/app\\app (1049).jpg',
#  './test/train_raw/app\\app (105).jpg',
#  './test/train_raw/app\\app (1050).jpg',
#  './test/train_raw/app\\app (1051).jpg',
#  './test/train_raw/app\\app (1052).jpg',
#  './test/train_raw/app\\app (1053).jpg',
#  './test/train_raw/app\\app (1054).jpg',
#  './test/train_raw/app\\app (1055).jpg',
#  './test/train_raw/app\\app (1056).jpg',
#  './test/train_raw/app\\app (1057).jpg',
#  './test/train_raw/app\\app (1058).jpg',
#  './test/train_raw/app\\app (1059).jpg',
#  './test/train_raw/app\\app (106).jpg',
#  './test/train_raw/app\\app (1060).jpg',
#  './test/train_raw/app\\app (1061).jpg',
#  './test/train_raw/app\\app (1062).jpg',
#  './test/train_raw/app\\app (1063).jpg',
#  './test/train_raw/app\\app (1064).jpg',
#  './test/train_raw/app\\app (1065).jpg',
#  './test/train_raw/app\\app (1066).jpg',
#  './test/train_raw/app\\app (1067).jpg',
#  './test/train_raw/app\\app (1068).jpg',
#  './test/train_raw/app\\app (1069).jpg',
#  './test/train_raw/app\\app (107).jpg',
#  './test/train_raw/app\\app (1070).jpg',
#  './test/train_raw/app\\app (1071).jpg',
#  './test/train_raw/app\\app (1072).jpg',
#  './test/train_raw/app\\app (1073).jpg',
#  './test/train_raw/app\\app (1074).jpg',
#  './test/train_raw/app\\app (1075).jpg',
#  './test/train_raw/app\\app (1076).jpg',
#  './test/train_raw/app\\app (1077).jpg',
#  './test/train_raw/app\\app (1078).jpg',
#  './test/train_raw/app\\app (1079).jpg',
#  './test/train_raw/app\\app (108).jpg',
#  './test/train_raw/app\\app (1080).jpg',
#  './test/train_raw/app\\app (1081).jpg',
#  './test/train_raw/app\\app (1082).jpg',
#  './test/train_raw/app\\app (1083).jpg',
#  './test/train_raw/app\\app (1084).jpg',
#  './test/train_raw/app\\app (1085).jpg',
#  './test/train_raw/app\\app (1086).jpg',
#  './test/train_raw/app\\app (1087).jpg',
#  './test/train_raw/app\\app (1088).jpg',
#  './test/train_raw/app\\app (1089).jpg',
#  './test/train_raw/app\\app (109).jpg',
#  './test/train_raw/app\\app (1090).jpg',
#  './test/train_raw/app\\app (1091).jpg',
#  './test/train_raw/app\\app (1092).jpg',
#  './test/train_raw/app\\app (1093).jpg',
#  './test/train_raw/app\\app (1094).jpg',
#  './test/train_raw/app\\app (1095).jpg',
#  './test/train_raw/app\\app (1096).jpg',
#  './test/train_raw/app\\app (1097).jpg',
#  './test/train_raw/app\\app (1098).jpg',
#  './test/train_raw/app\\app (1099).jpg',
#  './test/train_raw/app\\app (11).jpg',
#  './test/train_raw/app\\app (110).jpg',
#  './test/train_raw/app\\app (1100).jpg',
#  './test/train_raw/app\\app (1101).jpg',
#  './test/train_raw/app\\app (1102).jpg',
#  './test/train_raw/app\\app (1103).jpg',
#  './test/train_raw/app\\app (1104).jpg',
#  './test/train_raw/app\\app (1105).jpg',
#  './test/train_raw/app\\app (1106).jpg',
#  './test/train_raw/app\\app (1107).jpg',
#  './test/train_raw/app\\app (1108).jpg',
#  './test/train_raw/app\\app (1109).jpg',
#  './test/train_raw/app\\app (111).jpg',
#  './test/train_raw/app\\app (1110).jpg',
#  './test/train_raw/app\\app (1111).jpg',
#  './test/train_raw/app\\app (1112).jpg',
#  './test/train_raw/app\\app (1113).jpg',
#  './test/train_raw/app\\app (1114).jpg',
#  './test/train_raw/app\\app (1115).jpg',
#  './test/train_raw/app\\app (1116).jpg',
#  './test/train_raw/app\\app (1117).jpg',
#  './test/train_raw/app\\app (1118).jpg',
#  './test/train_raw/app\\app (1119).jpg',
#  './test/train_raw/app\\app (112).jpg',
#  './test/train_raw/app\\app (1120).jpg',
#  './test/train_raw/app\\app (1121).jpg',
#  './test/train_raw/app\\app (1122).jpg',
#  './test/train_raw/app\\app (1123).jpg',
#  './test/train_raw/app\\app (1124).jpg',
#  './test/train_raw/app\\app (1125).jpg',
#  './test/train_raw/app\\app (1126).jpg',
#  './test/train_raw/app\\app (1127).jpg',
#  './test/train_raw/app\\app (1128).jpg',
#  './test/train_raw/app\\app (1129).jpg',
#  './test/train_raw/app\\app (113).jpg',
#  './test/train_raw/app\\app (1130).jpg',
#  './test/train_raw/app\\app (1131).jpg',
#  './test/train_raw/app\\app (1132).jpg',
#  './test/train_raw/app\\app (1133).jpg',
#  './test/train_raw/app\\app (1134).jpg',
#  './test/train_raw/app\\app (1135).jpg',
#  './test/train_raw/app\\app (1136).jpg',
#  './test/train_raw/app\\app (1137).jpg',
#  './test/train_raw/app\\app (1138).jpg',
#  './test/train_raw/app\\app (1139).jpg',
#  './test/train_raw/app\\app (114).jpg',
#  './test/train_raw/app\\app (1140).jpg',
#  './test/train_raw/app\\app (1141).jpg',
#  './test/train_raw/app\\app (1142).jpg',
#  './test/train_raw/app\\app (1143).jpg',
#  './test/train_raw/app\\app (1144).jpg',
#  './test/train_raw/app\\app (1145).jpg',
#  './test/train_raw/app\\app (1146).jpg',
#  './test/train_raw/app\\app (1147).jpg',
#  './test/train_raw/app\\app (1148).jpg',
#  './test/train_raw/app\\app (1149).jpg',
#  './test/train_raw/app\\app (115).jpg',
#  './test/train_raw/app\\app (1150).jpg',
#  './test/train_raw/app\\app (1151).jpg',
#  './test/train_raw/app\\app (1152).jpg',
#  './test/train_raw/app\\app (1153).jpg',
#  './test/train_raw/app\\app (1154).jpg',
#  './test/train_raw/app\\app (1155).jpg',
#  './test/train_raw/app\\app (1156).jpg',
#  './test/train_raw/app\\app (1157).jpg',
#  './test/train_raw/app\\app (1158).jpg',
#  './test/train_raw/app\\app (1159).jpg',
#  './test/train_raw/app\\app (116).jpg',
#  './test/train_raw/app\\app (1160).jpg',
#  './test/train_raw/app\\app (1161).jpg',
#  './test/train_raw/app\\app (1162).jpg',
#  './test/train_raw/app\\app (1163).jpg',
#  './test/train_raw/app\\app (1164).jpg',
#  './test/train_raw/app\\app (1165).jpg',
#  './test/train_raw/app\\app (1166).jpg',
#  './test/train_raw/app\\app (1167).jpg',
#  './test/train_raw/app\\app (1168).jpg',
#  './test/train_raw/app\\app (1169).jpg',
#  './test/train_raw/app\\app (117).jpg',
#  './test/train_raw/app\\app (1170).jpg',
#  './test/train_raw/app\\app (1171).jpg',
#  './test/train_raw/app\\app (1172).jpg',
#  './test/train_raw/app\\app (1173).jpg',
#  './test/train_raw/app\\app (1174).jpg',
#  './test/train_raw/app\\app (1175).jpg',
#  './test/train_raw/app\\app (1176).jpg',
#  './test/train_raw/app\\app (1177).jpg',
#  './test/train_raw/app\\app (1178).jpg',
#  './test/train_raw/app\\app (1179).jpg',
#  './test/train_raw/app\\app (118).jpg',
#  './test/train_raw/app\\app (1180).jpg',
#  './test/train_raw/app\\app (1181).jpg',
#  './test/train_raw/app\\app (1182).jpg',
#  './test/train_raw/app\\app (1183).jpg',
#  './test/train_raw/app\\app (1184).jpg',
#  './test/train_raw/app\\app (1185).jpg',
#  './test/train_raw/app\\app (1186).jpg',
#  './test/train_raw/app\\app (1187).jpg',
#  './test/train_raw/app\\app (1188).jpg',
#  './test/train_raw/app\\app (1189).jpg',
#  './test/train_raw/app\\app (119).jpg',
#  './test/train_raw/app\\app (1190).jpg',
#  './test/train_raw/app\\app (1191).jpg',
#  './test/train_raw/app\\app (1192).jpg',
#  './test/train_raw/app\\app (1193).jpg',
#  './test/train_raw/app\\app (1194).jpg',
#  './test/train_raw/app\\app (1195).jpg',
#  './test/train_raw/app\\app (1196).jpg',
#  './test/train_raw/app\\app (1197).jpg',
#  './test/train_raw/app\\app (1198).jpg',
#  './test/train_raw/app\\app (1199).jpg',
#  './test/train_raw/app\\app (12).jpg',
#  './test/train_raw/app\\app (120).jpg',
#  './test/train_raw/app\\app (1200).jpg',
#  './test/train_raw/app\\app (1201).jpg',
#  './test/train_raw/app\\app (1202).jpg',
#  './test/train_raw/app\\app (1203).jpg',
#  './test/train_raw/app\\app (1204).jpg',
#  './test/train_raw/app\\app (1205).jpg',
#  './test/train_raw/app\\app (1206).jpg',
#  './test/train_raw/app\\app (1207).jpg',
#  './test/train_raw/app\\app (1208).jpg',
#  './test/train_raw/app\\app (1209).jpg',
#  './test/train_raw/app\\app (121).jpg',
#  './test/train_raw/app\\app (1210).jpg',
#  './test/train_raw/app\\app (1211).jpg',
#  './test/train_raw/app\\app (1212).jpg',
#  './test/train_raw/app\\app (1213).jpg',
#  './test/train_raw/app\\app (1214).jpg',
#  './test/train_raw/app\\app (1215).jpg',
#  './test/train_raw/app\\app (1216).jpg',
#  './test/train_raw/app\\app (1217).jpg',
#  './test/train_raw/app\\app (1218).jpg',
#  './test/train_raw/app\\app (1219).jpg',
#  './test/train_raw/app\\app (122).jpg',
#  './test/train_raw/app\\app (1220).jpg',
#  './test/train_raw/app\\app (1221).jpg',
#  './test/train_raw/app\\app (1222).jpg',
#  './test/train_raw/app\\app (1223).jpg',
#  './test/train_raw/app\\app (1224).jpg',
#  './test/train_raw/app\\app (1225).jpg',
#  './test/train_raw/app\\app (1226).jpg',
#  './test/train_raw/app\\app (1227).jpg',
#  './test/train_raw/app\\app (1228).jpg',
#  './test/train_raw/app\\app (1229).jpg',
#  './test/train_raw/app\\app (123).jpg',
#  './test/train_raw/app\\app (1230).jpg',
#  './test/train_raw/app\\app (1231).jpg',
#  './test/train_raw/app\\app (1232).jpg',
#  './test/train_raw/app\\app (1233).jpg',
#  './test/train_raw/app\\app (1234).jpg',
#  './test/train_raw/app\\app (1235).jpg',
#  './test/train_raw/app\\app (1236).jpg',
#  './test/train_raw/app\\app (1237).jpg',
#  './test/train_raw/app\\app (1238).jpg',
#  './test/train_raw/app\\app (1239).jpg',
#  './test/train_raw/app\\app (124).jpg',
#  './test/train_raw/app\\app (1240).jpg',
#  './test/train_raw/app\\app (1241).jpg',
#  './test/train_raw/app\\app (1242).jpg',
#  './test/train_raw/app\\app (1243).jpg',
#  './test/train_raw/app\\app (1244).jpg',
#  './test/train_raw/app\\app (1245).jpg',
#  './test/train_raw/app\\app (1246).jpg',
#  './test/train_raw/app\\app (1247).jpg',
#  './test/train_raw/app\\app (1248).jpg',
#  './test/train_raw/app\\app (1249).jpg',
#  './test/train_raw/app\\app (125).jpg',
#  './test/train_raw/app\\app (1250).jpg',
#  './test/train_raw/app\\app (1251).jpg',
#  './test/train_raw/app\\app (1252).jpg',
#  './test/train_raw/app\\app (1253).jpg',
#  './test/train_raw/app\\app (1254).jpg',
#  './test/train_raw/app\\app (1255).jpg',
#  './test/train_raw/app\\app (1256).jpg',
#  './test/train_raw/app\\app (1257).jpg',
#  './test/train_raw/app\\app (1258).jpg',
#  './test/train_raw/app\\app (1259).jpg',
#  './test/train_raw/app\\app (126).jpg',
#  './test/train_raw/app\\app (1260).jpg',
#  './test/train_raw/app\\app (1261).jpg',
#  './test/train_raw/app\\app (1262).jpg',
#  './test/train_raw/app\\app (1263).jpg',
#  './test/train_raw/app\\app (1264).jpg',
#  './test/train_raw/app\\app (1265).jpg',
#  './test/train_raw/app\\app (1266).jpg',
#  './test/train_raw/app\\app (1267).jpg',
#  './test/train_raw/app\\app (1268).jpg',
#  './test/train_raw/app\\app (1269).jpg',
#  './test/train_raw/app\\app (127).jpg',
#  './test/train_raw/app\\app (1270).jpg',
#  './test/train_raw/app\\app (1271).jpg',
#  './test/train_raw/app\\app (1272).jpg',
#  './test/train_raw/app\\app (1273).jpg',
#  './test/train_raw/app\\app (1274).jpg',
#  './test/train_raw/app\\app (1275).jpg',
#  './test/train_raw/app\\app (1276).jpg',
#  './test/train_raw/app\\app (1277).jpg',
#  './test/train_raw/app\\app (1278).jpg',
#  './test/train_raw/app\\app (1279).jpg',
#  './test/train_raw/app\\app (128).jpg',
#  './test/train_raw/app\\app (1280).jpg',
#  './test/train_raw/app\\app (1281).jpg',
#  './test/train_raw/app\\app (1282).jpg',
#  './test/train_raw/app\\app (1283).jpg',
#  './test/train_raw/app\\app (1284).jpg',
#  './test/train_raw/app\\app (1285).jpg',
#  './test/train_raw/app\\app (1286).jpg',
#  './test/train_raw/app\\app (1287).jpg',
#  './test/train_raw/app\\app (1288).jpg',
#  './test/train_raw/app\\app (1289).jpg',
#  './test/train_raw/app\\app (129).jpg',
#  './test/train_raw/app\\app (1290).jpg',
#  './test/train_raw/app\\app (1291).jpg',
#  './test/train_raw/app\\app (1292).jpg',
#  './test/train_raw/app\\app (1293).jpg',
#  './test/train_raw/app\\app (1294).jpg',
#  './test/train_raw/app\\app (1295).jpg',
#  './test/train_raw/app\\app (1296).jpg',
#  './test/train_raw/app\\app (1297).jpg',
#  './test/train_raw/app\\app (1298).jpg',
#  './test/train_raw/app\\app (1299).jpg',
#  './test/train_raw/app\\app (13).jpg',
#  './test/train_raw/app\\app (130).jpg',
#  './test/train_raw/app\\app (1300).jpg',
#  './test/train_raw/app\\app (1301).jpg',
#  './test/train_raw/app\\app (1302).jpg',
#  './test/train_raw/app\\app (1303).jpg',
#  './test/train_raw/app\\app (1304).jpg',
#  './test/train_raw/app\\app (1305).jpg',
#  './test/train_raw/app\\app (1306).jpg',
#  './test/train_raw/app\\app (1307).jpg',
#  './test/train_raw/app\\app (1308).jpg',
#  './test/train_raw/app\\app (1309).jpg',
#  './test/train_raw/app\\app (131).jpg',
#  './test/train_raw/app\\app (1310).jpg',
#  './test/train_raw/app\\app (1311).jpg',
#  './test/train_raw/app\\app (1312).jpg',
#  './test/train_raw/app\\app (1313).jpg',
#  './test/train_raw/app\\app (1314).jpg',
#  './test/train_raw/app\\app (1315).jpg',
#  './test/train_raw/app\\app (1316).jpg',
#  './test/train_raw/app\\app (1317).jpg',
#  './test/train_raw/app\\app (1318).jpg',
#  './test/train_raw/app\\app (1319).jpg',
#  './test/train_raw/app\\app (132).jpg',
#  './test/train_raw/app\\app (1320).jpg',
#  './test/train_raw/app\\app (1321).jpg',
#  './test/train_raw/app\\app (1322).jpg',
#  './test/train_raw/app\\app (1323).jpg',
#  './test/train_raw/app\\app (1324).jpg',
#  './test/train_raw/app\\app (1325).jpg',
#  './test/train_raw/app\\app (1326).jpg',
#  './test/train_raw/app\\app (1327).jpg',
#  './test/train_raw/app\\app (1328).jpg',
#  './test/train_raw/app\\app (1329).jpg',
#  './test/train_raw/app\\app (133).jpg',
#  './test/train_raw/app\\app (1330).jpg',
#  './test/train_raw/app\\app (1331).jpg',
#  './test/train_raw/app\\app (1332).jpg',
#  './test/train_raw/app\\app (1333).jpg',
#  './test/train_raw/app\\app (1334).jpg',
#  './test/train_raw/app\\app (1335).jpg',
#  './test/train_raw/app\\app (1336).jpg',
#  './test/train_raw/app\\app (1337).jpg',
#  './test/train_raw/app\\app (1338).jpg',
#  './test/train_raw/app\\app (1339).jpg',
#  './test/train_raw/app\\app (134).jpg',
#  './test/train_raw/app\\app (1340).jpg',
#  './test/train_raw/app\\app (1341).jpg',
#  './test/train_raw/app\\app (1342).jpg',
#  './test/train_raw/app\\app (1343).jpg',
#  './test/train_raw/app\\app (1344).jpg',
#  './test/train_raw/app\\app (1345).jpg',
#  './test/train_raw/app\\app (1346).jpg',
#  './test/train_raw/app\\app (1347).jpg',
#  './test/train_raw/app\\app (1348).jpg',
#  './test/train_raw/app\\app (1349).jpg',
#  './test/train_raw/app\\app (135).jpg',
#  './test/train_raw/app\\app (1350).jpg',
#  './test/train_raw/app\\app (1351).jpg',
#  './test/train_raw/app\\app (1352).jpg',
#  './test/train_raw/app\\app (1353).jpg',
#  './test/train_raw/app\\app (1354).jpg',
#  './test/train_raw/app\\app (1355).jpg',
#  './test/train_raw/app\\app (1356).jpg',
#  './test/train_raw/app\\app (1357).jpg',
#  './test/train_raw/app\\app (1358).jpg',
#  './test/train_raw/app\\app (1359).jpg',
#  './test/train_raw/app\\app (136).jpg',
#  './test/train_raw/app\\app (1360).jpg',
#  './test/train_raw/app\\app (1361).jpg',
#  './test/train_raw/app\\app (1362).jpg',
#  './test/train_raw/app\\app (1363).jpg',
#  './test/train_raw/app\\app (1364).jpg',
#  './test/train_raw/app\\app (1365).jpg',
#  './test/train_raw/app\\app (1366).jpg',
#  './test/train_raw/app\\app (1367).jpg',
#  './test/train_raw/app\\app (1368).jpg',
#  './test/train_raw/app\\app (1369).jpg',
#  './test/train_raw/app\\app (137).jpg',
#  './test/train_raw/app\\app (1370).jpg',
#  './test/train_raw/app\\app (1371).jpg',
#  './test/train_raw/app\\app (1372).jpg',
#  './test/train_raw/app\\app (1373).jpg',
#  './test/train_raw/app\\app (1374).jpg',
#  './test/train_raw/app\\app (1375).jpg',
#  './test/train_raw/app\\app (1376).jpg',
#  './test/train_raw/app\\app (1377).jpg',
#  './test/train_raw/app\\app (1378).jpg',
#  './test/train_raw/app\\app (1379).jpg',
#  './test/train_raw/app\\app (138).jpg',
#  './test/train_raw/app\\app (1380).jpg',
#  './test/train_raw/app\\app (1381).jpg',
#  './test/train_raw/app\\app (1382).jpg',
#  './test/train_raw/app\\app (1383).jpg',
#  './test/train_raw/app\\app (1384).jpg',
#  './test/train_raw/app\\app (1385).jpg',
#  './test/train_raw/app\\app (1386).jpg',
#  './test/train_raw/app\\app (1387).jpg',
#  './test/train_raw/app\\app (1388).jpg',
#  './test/train_raw/app\\app (1389).jpg',
#  './test/train_raw/app\\app (139).jpg',
#  './test/train_raw/app\\app (1390).jpg',
#  './test/train_raw/app\\app (1391).jpg',
#  './test/train_raw/app\\app (1392).jpg',
#  './test/train_raw/app\\app (1393).jpg',
#  './test/train_raw/app\\app (1394).jpg',
#  './test/train_raw/app\\app (1395).jpg',
#  './test/train_raw/app\\app (1396).jpg',
#  './test/train_raw/app\\app (1397).jpg',
#  './test/train_raw/app\\app (1398).jpg',
#  './test/train_raw/app\\app (1399).jpg',
#  './test/train_raw/app\\app (14).jpg',
#  './test/train_raw/app\\app (140).jpg',
#  './test/train_raw/app\\app (1400).jpg',
#  './test/train_raw/app\\app (1401).jpg',
#  './test/train_raw/app\\app (1402).jpg',
#  './test/train_raw/app\\app (1403).jpg',
#  './test/train_raw/app\\app (1404).jpg',
#  './test/train_raw/app\\app (1405).jpg',
#  './test/train_raw/app\\app (1406).jpg',
#  './test/train_raw/app\\app (1407).jpg',
#  './test/train_raw/app\\app (1408).jpg',
#  './test/train_raw/app\\app (1409).jpg',
#  './test/train_raw/app\\app (141).jpg',
#  './test/train_raw/app\\app (1410).jpg',
#  './test/train_raw/app\\app (1411).jpg',
#  './test/train_raw/app\\app (1412).jpg',
#  './test/train_raw/app\\app (1413).jpg',
#  './test/train_raw/app\\app (1414).jpg',
#  './test/train_raw/app\\app (1415).jpg',
#  './test/train_raw/app\\app (1416).jpg',
#  './test/train_raw/app\\app (1417).jpg',
#  './test/train_raw/app\\app (1418).jpg',
#  './test/train_raw/app\\app (1419).jpg',
#  './test/train_raw/app\\app (142).jpg',
#  './test/train_raw/app\\app (1420).jpg',
#  './test/train_raw/app\\app (1421).jpg',
#  './test/train_raw/app\\app (1422).jpg',
#  './test/train_raw/app\\app (1423).jpg',
#  './test/train_raw/app\\app (1424).jpg',
#  './test/train_raw/app\\app (1425).jpg',
#  './test/train_raw/app\\app (1426).jpg',
#  './test/train_raw/app\\app (1427).jpg',
#  './test/train_raw/app\\app (1428).jpg',
#  './test/train_raw/app\\app (1429).jpg',
#  './test/train_raw/app\\app (143).jpg',
#  './test/train_raw/app\\app (1430).jpg',
#  './test/train_raw/app\\app (1431).jpg',
#  './test/train_raw/app\\app (1432).jpg',
#  './test/train_raw/app\\app (1433).jpg',
#  './test/train_raw/app\\app (1434).jpg',
#  './test/train_raw/app\\app (1435).jpg',
#  './test/train_raw/app\\app (1436).jpg',
#  './test/train_raw/app\\app (1437).jpg',
#  './test/train_raw/app\\app (1438).jpg',
#  './test/train_raw/app\\app (1439).jpg',
#  './test/train_raw/app\\app (144).jpg',
#  './test/train_raw/app\\app (1440).jpg',
#  './test/train_raw/app\\app (1441).jpg',
#  './test/train_raw/app\\app (1442).jpg',
#  './test/train_raw/app\\app (1443).jpg',
#  './test/train_raw/app\\app (1444).jpg',
#  './test/train_raw/app\\app (1445).jpg',
#  './test/train_raw/app\\app (1446).jpg',
#  './test/train_raw/app\\app (1447).jpg',
#  './test/train_raw/app\\app (1448).jpg',
#  './test/train_raw/app\\app (1449).jpg',
#  './test/train_raw/app\\app (145).jpg',
#  './test/train_raw/app\\app (1450).jpg',
#  './test/train_raw/app\\app (1451).jpg',
#  './test/train_raw/app\\app (1452).jpg',
#  './test/train_raw/app\\app (1453).jpg',
#  './test/train_raw/app\\app (1454).jpg',
#  './test/train_raw/app\\app (1455).jpg',
#  './test/train_raw/app\\app (1456).jpg',
#  './test/train_raw/app\\app (1457).jpg',
#  './test/train_raw/app\\app (1458).jpg',
#  './test/train_raw/app\\app (1459).jpg',
#  './test/train_raw/app\\app (146).jpg',
#  './test/train_raw/app\\app (1460).jpg',
#  './test/train_raw/app\\app (1461).jpg',
#  './test/train_raw/app\\app (1462).jpg',
#  './test/train_raw/app\\app (1463).jpg',
#  './test/train_raw/app\\app (1464).jpg',
#  './test/train_raw/app\\app (1465).jpg',
#  './test/train_raw/app\\app (1466).jpg',
#  './test/train_raw/app\\app (1467).jpg',
#  './test/train_raw/app\\app (1468).jpg',
#  './test/train_raw/app\\app (1469).jpg',
#  './test/train_raw/app\\app (147).jpg',
#  './test/train_raw/app\\app (1470).jpg',
#  './test/train_raw/app\\app (1471).jpg',
#  './test/train_raw/app\\app (1472).jpg',
#  './test/train_raw/app\\app (1473).jpg',
#  './test/train_raw/app\\app (1474).jpg',
#  './test/train_raw/app\\app (1475).jpg',
#  './test/train_raw/app\\app (1476).jpg',
#  './test/train_raw/app\\app (1477).jpg',
#  './test/train_raw/app\\app (1478).jpg',
#  './test/train_raw/app\\app (1479).jpg',
#  './test/train_raw/app\\app (148).jpg',
#  './test/train_raw/app\\app (1480).jpg',
#  './test/train_raw/app\\app (1481).jpg',
#  './test/train_raw/app\\app (1482).jpg',
#  './test/train_raw/app\\app (1483).jpg',
#  './test/train_raw/app\\app (1484).jpg',
#  './test/train_raw/app\\app (1485).jpg',
#  './test/train_raw/app\\app (1486).jpg',
#  './test/train_raw/app\\app (1487).jpg',
#  './test/train_raw/app\\app (1488).jpg',
#  './test/train_raw/app\\app (1489).jpg',
#  './test/train_raw/app\\app (149).jpg',
#  './test/train_raw/app\\app (1490).jpg',
#  './test/train_raw/app\\app (1491).jpg',
#  './test/train_raw/app\\app (1492).jpg',
#  './test/train_raw/app\\app (1493).jpg',
#  './test/train_raw/app\\app (1494).jpg',
#  './test/train_raw/app\\app (1495).jpg',
#  './test/train_raw/app\\app (1496).jpg',
#  './test/train_raw/app\\app (1497).jpg',
#  './test/train_raw/app\\app (1498).jpg',
#  './test/train_raw/app\\app (1499).jpg',
#  './test/train_raw/app\\app (15).jpg',
#  './test/train_raw/app\\app (150).jpg',
#  './test/train_raw/app\\app (1500).jpg',
#  './test/train_raw/app\\app (1501).jpg',
#  './test/train_raw/app\\app (1502).jpg',
#  './test/train_raw/app\\app (1503).jpg',
#  './test/train_raw/app\\app (1504).jpg',
#  './test/train_raw/app\\app (1505).jpg',
#  './test/train_raw/app\\app (1506).jpg',
#  './test/train_raw/app\\app (1507).jpg',
#  './test/train_raw/app\\app (1508).jpg',
#  './test/train_raw/app\\app (1509).jpg',
#  './test/train_raw/app\\app (151).jpg',
#  './test/train_raw/app\\app (1510).jpg',
#  './test/train_raw/app\\app (1511).jpg',
#  './test/train_raw/app\\app (1512).jpg',
#  './test/train_raw/app\\app (1513).jpg',
#  './test/train_raw/app\\app (1514).jpg',
#  './test/train_raw/app\\app (1515).jpg',
#  './test/train_raw/app\\app (1516).jpg',
#  './test/train_raw/app\\app (1517).jpg',
#  './test/train_raw/app\\app (1518).jpg',
#  './test/train_raw/app\\app (1519).jpg',
#  './test/train_raw/app\\app (152).jpg',
#  './test/train_raw/app\\app (1520).jpg',
#  './test/train_raw/app\\app (1521).jpg',
#  './test/train_raw/app\\app (1522).jpg',
#  './test/train_raw/app\\app (1523).jpg',
#  './test/train_raw/app\\app (1524).jpg',
#  './test/train_raw/app\\app (1525).jpg',
#  './test/train_raw/app\\app (1526).jpg',
#  './test/train_raw/app\\app (1527).jpg',
#  './test/train_raw/app\\app (1528).jpg',
#  './test/train_raw/app\\app (1529).jpg',
#  './test/train_raw/app\\app (153).jpg',
#  './test/train_raw/app\\app (1530).jpg',
#  './test/train_raw/app\\app (1531).jpg',
#  './test/train_raw/app\\app (1532).jpg',
#  './test/train_raw/app\\app (1533).jpg',
#  './test/train_raw/app\\app (1534).jpg',
#  './test/train_raw/app\\app (1535).jpg',
#  './test/train_raw/app\\app (1536).jpg',
#  './test/train_raw/app\\app (1537).jpg',
#  './test/train_raw/app\\app (1538).jpg',
#  './test/train_raw/app\\app (1539).jpg',
#  './test/train_raw/app\\app (154).jpg',
#  './test/train_raw/app\\app (1540).jpg',
#  './test/train_raw/app\\app (1541).jpg',
#  './test/train_raw/app\\app (1542).jpg',
#  './test/train_raw/app\\app (1543).jpg',
#  './test/train_raw/app\\app (1544).jpg',
#  './test/train_raw/app\\app (1545).jpg',
#  './test/train_raw/app\\app (1546).jpg',
#  './test/train_raw/app\\app (1547).jpg',
#  './test/train_raw/app\\app (1548).jpg',
#  './test/train_raw/app\\app (1549).jpg',
#  './test/train_raw/app\\app (155).jpg',
#  './test/train_raw/app\\app (1550).jpg',
#  './test/train_raw/app\\app (1551).jpg',
#  './test/train_raw/app\\app (1552).jpg',
#  './test/train_raw/app\\app (1553).jpg',
#  './test/train_raw/app\\app (1554).jpg',
#  './test/train_raw/app\\app (1555).jpg',
#  './test/train_raw/app\\app (1556).jpg',
#  './test/train_raw/app\\app (1557).jpg',
#  './test/train_raw/app\\app (1558).jpg',
#  './test/train_raw/app\\app (1559).jpg',
#  './test/train_raw/app\\app (156).jpg',
#  './test/train_raw/app\\app (1560).jpg',
#  './test/train_raw/app\\app (1561).jpg',
#  './test/train_raw/app\\app (1562).jpg',
#  './test/train_raw/app\\app (1563).jpg',
#  './test/train_raw/app\\app (1564).jpg',
#  './test/train_raw/app\\app (1565).jpg',
#  './test/train_raw/app\\app (1566).jpg',
#  './test/train_raw/app\\app (1567).jpg',
#  './test/train_raw/app\\app (1568).jpg',
#  './test/train_raw/app\\app (1569).jpg',
#  './test/train_raw/app\\app (157).jpg',
#  './test/train_raw/app\\app (1570).jpg',
#  './test/train_raw/app\\app (1571).jpg',
#  './test/train_raw/app\\app (1572).jpg',
#  './test/train_raw/app\\app (1573).jpg',
#  './test/train_raw/app\\app (1574).jpg',
#  './test/train_raw/app\\app (1575).jpg',
#  './test/train_raw/app\\app (1576).jpg',
#  './test/train_raw/app\\app (1577).jpg',
#  './test/train_raw/app\\app (1578).jpg',
#  './test/train_raw/app\\app (1579).jpg',
#  './test/train_raw/app\\app (158).jpg',
#  './test/train_raw/app\\app (1580).jpg',
#  './test/train_raw/app\\app (1581).jpg',
#  './test/train_raw/app\\app (1582).jpg',
#  './test/train_raw/app\\app (1583).jpg',
#  './test/train_raw/app\\app (1584).jpg',
#  './test/train_raw/app\\app (1585).jpg',
#  './test/train_raw/app\\app (1586).jpg',
#  './test/train_raw/app\\app (1587).jpg',
#  './test/train_raw/app\\app (1588).jpg',
#  './test/train_raw/app\\app (1589).jpg',
#  './test/train_raw/app\\app (159).jpg',
#  './test/train_raw/app\\app (1590).jpg',
#  './test/train_raw/app\\app (1591).jpg',
#  './test/train_raw/app\\app (1592).jpg',
#  './test/train_raw/app\\app (1593).jpg',
#  './test/train_raw/app\\app (1594).jpg',
#  './test/train_raw/app\\app (1595).jpg',
#  './test/train_raw/app\\app (1596).jpg',
#  './test/train_raw/app\\app (1597).jpg',
#  './test/train_raw/app\\app (1598).jpg',
#  './test/train_raw/app\\app (1599).jpg',
#  './test/train_raw/app\\app (16).jpg',
#  './test/train_raw/app\\app (160).jpg',
#  './test/train_raw/app\\app (1600).jpg',
#  './test/train_raw/app\\app (1601).jpg',
#  './test/train_raw/app\\app (1602).jpg',
#  './test/train_raw/app\\app (1603).jpg',
#  './test/train_raw/app\\app (1604).jpg',
#  './test/train_raw/app\\app (1605).jpg',
#  './test/train_raw/app\\app (1606).jpg',
#  './test/train_raw/app\\app (1607).jpg',
#  './test/train_raw/app\\app (1608).jpg',
#  './test/train_raw/app\\app (1609).jpg',
#  './test/train_raw/app\\app (161).jpg',
#  './test/train_raw/app\\app (1610).jpg',
#  './test/train_raw/app\\app (1611).jpg',
#  './test/train_raw/app\\app (1612).jpg',
#  './test/train_raw/app\\app (1613).jpg',
#  './test/train_raw/app\\app (1614).jpg',
#  './test/train_raw/app\\app (1615).jpg',
#  './test/train_raw/app\\app (1616).jpg',
#  './test/train_raw/app\\app (1617).jpg',
#  './test/train_raw/app\\app (1618).jpg',
#  './test/train_raw/app\\app (1619).jpg',
#  './test/train_raw/app\\app (162).jpg',
#  './test/train_raw/app\\app (1620).jpg',
#  './test/train_raw/app\\app (1621).jpg',
#  './test/train_raw/app\\app (1622).jpg',
#  './test/train_raw/app\\app (1623).jpg',
#  './test/train_raw/app\\app (1624).jpg',
#  './test/train_raw/app\\app (1625).jpg',
#  './test/train_raw/app\\app (1626).jpg',
#  './test/train_raw/app\\app (1627).jpg',
#  './test/train_raw/app\\app (1628).jpg',
#  './test/train_raw/app\\app (1629).jpg',
#  './test/train_raw/app\\app (163).jpg',
#  './test/train_raw/app\\app (1630).jpg',
#  './test/train_raw/app\\app (1631).jpg',
#  './test/train_raw/app\\app (1632).jpg',
#  './test/train_raw/app\\app (1633).jpg',
#  './test/train_raw/app\\app (1634).jpg',
#  './test/train_raw/app\\app (1635).jpg',
#  './test/train_raw/app\\app (1636).jpg',
#  './test/train_raw/app\\app (1637).jpg',
#  './test/train_raw/app\\app (1638).jpg',
#  './test/train_raw/app\\app (1639).jpg',
#  './test/train_raw/app\\app (164).jpg',
#  './test/train_raw/app\\app (1640).jpg',
#  './test/train_raw/app\\app (1641).jpg',
#  './test/train_raw/app\\app (1642).jpg',
#  './test/train_raw/app\\app (1643).jpg',
#  './test/train_raw/app\\app (1644).jpg',
#  './test/train_raw/app\\app (1645).jpg',
#  './test/train_raw/app\\app (1646).jpg',
#  './test/train_raw/app\\app (1647).jpg',
#  './test/train_raw/app\\app (1648).jpg',
#  './test/train_raw/app\\app (1649).jpg',
#  './test/train_raw/app\\app (165).jpg',
#  './test/train_raw/app\\app (1650).jpg',
#  './test/train_raw/app\\app (1651).jpg',
#  './test/train_raw/app\\app (1652).jpg',
#  './test/train_raw/app\\app (1653).jpg',
#  './test/train_raw/app\\app (1654).jpg',
#  './test/train_raw/app\\app (1655).jpg',
#  './test/train_raw/app\\app (1656).jpg',
#  './test/train_raw/app\\app (1657).jpg',
#  './test/train_raw/app\\app (1658).jpg',
#  './test/train_raw/app\\app (1659).jpg',
#  './test/train_raw/app\\app (166).jpg',
#  './test/train_raw/app\\app (1660).jpg',
#  './test/train_raw/app\\app (1661).jpg',
#  './test/train_raw/app\\app (1662).jpg',
#  './test/train_raw/app\\app (1663).jpg',
#  './test/train_raw/app\\app (1664).jpg',
#  './test/train_raw/app\\app (1665).jpg',
#  './test/train_raw/app\\app (1666).jpg',
#  './test/train_raw/app\\app (1667).jpg',
#  './test/train_raw/app\\app (1668).jpg',
#  './test/train_raw/app\\app (1669).jpg',
#  './test/train_raw/app\\app (167).jpg',
#  './test/train_raw/app\\app (1670).jpg',
#  './test/train_raw/app\\app (1671).jpg',
#  './test/train_raw/app\\app (1672).jpg',
#  './test/train_raw/app\\app (1673).jpg',
#  './test/train_raw/app\\app (1674).jpg',
#  './test/train_raw/app\\app (1675).jpg',
#  './test/train_raw/app\\app (1676).jpg',
#  './test/train_raw/app\\app (1677).jpg',
#  './test/train_raw/app\\app (1678).jpg',
#  './test/train_raw/app\\app (1679).jpg',
#  './test/train_raw/app\\app (168).jpg',
#  './test/train_raw/app\\app (1680).jpg',
#  './test/train_raw/app\\app (1681).jpg',
#  './test/train_raw/app\\app (1682).jpg',
#  './test/train_raw/app\\app (1683).jpg',
#  './test/train_raw/app\\app (1684).jpg',
#  './test/train_raw/app\\app (1685).jpg',
#  './test/train_raw/app\\app (1686).jpg',
#  './test/train_raw/app\\app (1687).jpg',
#  './test/train_raw/app\\app (1688).jpg',
#  './test/train_raw/app\\app (1689).jpg',
#  './test/train_raw/app\\app (169).jpg',
#  './test/train_raw/app\\app (1690).jpg',
#  './test/train_raw/app\\app (1691).jpg',
#  './test/train_raw/app\\app (1692).jpg',
#  './test/train_raw/app\\app (1693).jpg',
#  './test/train_raw/app\\app (1694).jpg',
#  './test/train_raw/app\\app (1695).jpg',
#  './test/train_raw/app\\app (1696).jpg',
#  './test/train_raw/app\\app (1697).jpg',
#  './test/train_raw/app\\app (1698).jpg',
#  './test/train_raw/app\\app (1699).jpg',
#  './test/train_raw/app\\app (17).jpg',
#  './test/train_raw/app\\app (170).jpg',
#  './test/train_raw/app\\app (1700).jpg',
#  './test/train_raw/app\\app (1701).jpg',
#  './test/train_raw/app\\app (1702).jpg',
#  './test/train_raw/app\\app (1703).jpg',
#  './test/train_raw/app\\app (1704).jpg',
#  './test/train_raw/app\\app (1705).jpg',
#  './test/train_raw/app\\app (1706).jpg',
#  './test/train_raw/app\\app (1707).jpg',
#  './test/train_raw/app\\app (1708).jpg',
#  './test/train_raw/app\\app (1709).jpg',
#  './test/train_raw/app\\app (171).jpg',
#  './test/train_raw/app\\app (1710).jpg',
#  './test/train_raw/app\\app (1711).jpg',
#  './test/train_raw/app\\app (1712).jpg',
#  './test/train_raw/app\\app (1713).jpg',
#  './test/train_raw/app\\app (1714).jpg',
#  './test/train_raw/app\\app (1715).jpg',
#  './test/train_raw/app\\app (1716).jpg',
#  './test/train_raw/app\\app (1717).jpg',
#  './test/train_raw/app\\app (1718).jpg',
#  './test/train_raw/app\\app (1719).jpg',
#  './test/train_raw/app\\app (172).jpg',
#  './test/train_raw/app\\app (1720).jpg',
#  './test/train_raw/app\\app (1721).jpg',
#  './test/train_raw/app\\app (1722).jpg',
#  './test/train_raw/app\\app (1723).jpg',
#  './test/train_raw/app\\app (1724).jpg',
#  './test/train_raw/app\\app (1725).jpg',
#  './test/train_raw/app\\app (1726).jpg',
#  './test/train_raw/app\\app (1727).jpg',
#  './test/train_raw/app\\app (1728).jpg',
#  './test/train_raw/app\\app (1729).jpg',
#  './test/train_raw/app\\app (173).jpg',
#  './test/train_raw/app\\app (1730).jpg',
#  './test/train_raw/app\\app (1731).jpg',
#  './test/train_raw/app\\app (1732).jpg',
#  './test/train_raw/app\\app (1733).jpg',
#  './test/train_raw/app\\app (1734).jpg',
#  './test/train_raw/app\\app (1735).jpg',
#  './test/train_raw/app\\app (1736).jpg',
#  './test/train_raw/app\\app (1737).jpg',
#  './test/train_raw/app\\app (1738).jpg',
#  './test/train_raw/app\\app (1739).jpg',
#  './test/train_raw/app\\app (174).jpg',
#  './test/train_raw/app\\app (1740).jpg',
#  './test/train_raw/app\\app (1741).jpg',
#  './test/train_raw/app\\app (1742).jpg',
#  './test/train_raw/app\\app (1743).jpg',
#  './test/train_raw/app\\app (1744).jpg',
#  './test/train_raw/app\\app (1745).jpg',
#  './test/train_raw/app\\app (1746).jpg',
#  './test/train_raw/app\\app (1747).jpg',
#  './test/train_raw/app\\app (1748).jpg',
#  './test/train_raw/app\\app (1749).jpg',
#  './test/train_raw/app\\app (175).jpg',
#  './test/train_raw/app\\app (1750).jpg',
#  './test/train_raw/app\\app (1751).jpg',
#  './test/train_raw/app\\app (1752).jpg',
#  './test/train_raw/app\\app (1753).jpg',
#  './test/train_raw/app\\app (1754).jpg',
#  './test/train_raw/app\\app (1755).jpg',
#  './test/train_raw/app\\app (1756).jpg',
#  './test/train_raw/app\\app (1757).jpg',
#  './test/train_raw/app\\app (1758).jpg',
#  './test/train_raw/app\\app (1759).jpg',
#  './test/train_raw/app\\app (176).jpg',
#  './test/train_raw/app\\app (1760).jpg',
#  './test/train_raw/app\\app (1761).jpg',
#  './test/train_raw/app\\app (1762).jpg',
#  './test/train_raw/app\\app (1763).jpg',
#  './test/train_raw/app\\app (1764).jpg',
#  './test/train_raw/app\\app (1765).jpg',
#  './test/train_raw/app\\app (1766).jpg',
#  './test/train_raw/app\\app (1767).jpg',
#  './test/train_raw/app\\app (1768).jpg',
#  './test/train_raw/app\\app (1769).jpg',
#  './test/train_raw/app\\app (177).jpg',
#  './test/train_raw/app\\app (1770).jpg',
#  './test/train_raw/app\\app (1771).jpg',
#  './test/train_raw/app\\app (1772).jpg',
#  './test/train_raw/app\\app (1773).jpg',
#  './test/train_raw/app\\app (1774).jpg',
#  './test/train_raw/app\\app (1775).jpg',
#  './test/train_raw/app\\app (1776).jpg',
#  './test/train_raw/app\\app (1777).jpg',
#  './test/train_raw/app\\app (1778).jpg',
#  './test/train_raw/app\\app (1779).jpg',
#  './test/train_raw/app\\app (178).jpg',
#  './test/train_raw/app\\app (1780).jpg',
#  './test/train_raw/app\\app (1781).jpg',
#  './test/train_raw/app\\app (1782).jpg',
#  './test/train_raw/app\\app (1783).jpg',
#  './test/train_raw/app\\app (1784).jpg',
#  './test/train_raw/app\\app (1785).jpg',
#  './test/train_raw/app\\app (1786).jpg',
#  './test/train_raw/app\\app (1787).jpg',
#  './test/train_raw/app\\app (1788).jpg',
#  './test/train_raw/app\\app (1789).jpg',
#  './test/train_raw/app\\app (179).jpg',
#  './test/train_raw/app\\app (1790).jpg',
#  './test/train_raw/app\\app (1791).jpg',
#  './test/train_raw/app\\app (1792).jpg',
#  './test/train_raw/app\\app (1793).jpg',
#  './test/train_raw/app\\app (1794).jpg',
#  './test/train_raw/app\\app (1795).jpg',
#  './test/train_raw/app\\app (1796).jpg',
#  './test/train_raw/app\\app (1797).jpg',
#  './test/train_raw/app\\app (1798).jpg',
#  './test/train_raw/app\\app (1799).jpg',
#  './test/train_raw/app\\app (18).jpg',
#  './test/train_raw/app\\app (180).jpg',
#  './test/train_raw/app\\app (1800).jpg',
#  './test/train_raw/app\\app (1801).jpg',
#  './test/train_raw/app\\app (1802).jpg',
#  './test/train_raw/app\\app (1803).jpg',
#  './test/train_raw/app\\app (1804).jpg',
#  './test/train_raw/app\\app (1805).jpg',
#  './test/train_raw/app\\app (1806).jpg',
#  './test/train_raw/app\\app (1807).jpg',
#  './test/train_raw/app\\app (1808).jpg',
#  './test/train_raw/app\\app (1809).jpg',
#  './test/train_raw/app\\app (181).jpg',
#  './test/train_raw/app\\app (1810).jpg',
#  './test/train_raw/app\\app (1811).jpg',
#  './test/train_raw/app\\app (1812).jpg',
#  './test/train_raw/app\\app (1813).jpg',
#  './test/train_raw/app\\app (1814).jpg',
#  './test/train_raw/app\\app (1815).jpg',
#  './test/train_raw/app\\app (1816).jpg',
#  './test/train_raw/app\\app (1817).jpg',
#  './test/train_raw/app\\app (1818).jpg',
#  './test/train_raw/app\\app (1819).jpg',
#  './test/train_raw/app\\app (182).jpg',
#  './test/train_raw/app\\app (1820).jpg',
#  './test/train_raw/app\\app (1821).jpg',
#  './test/train_raw/app\\app (1822).jpg',
#  './test/train_raw/app\\app (1823).jpg',
#  './test/train_raw/app\\app (1824).jpg',
#  './test/train_raw/app\\app (1825).jpg',
#  './test/train_raw/app\\app (1826).jpg',
#  './test/train_raw/app\\app (1827).jpg',
#  './test/train_raw/app\\app (1828).jpg',
#  './test/train_raw/app\\app (1829).jpg',
#  './test/train_raw/app\\app (183).jpg',
#  './test/train_raw/app\\app (1830).jpg',
#  './test/train_raw/app\\app (1831).jpg',
#  './test/train_raw/app\\app (1832).jpg',
#  './test/train_raw/app\\app (1833).jpg',
#  './test/train_raw/app\\app (1834).jpg',
#  './test/train_raw/app\\app (1835).jpg',
#  './test/train_raw/app\\app (1836).jpg',
#  './test/train_raw/app\\app (1837).jpg',
#  './test/train_raw/app\\app (1838).jpg',
#  './test/train_raw/app\\app (1839).jpg',
#  './test/train_raw/app\\app (184).jpg',
#  './test/train_raw/app\\app (1840).jpg',
#  './test/train_raw/app\\app (1841).jpg',
#  './test/train_raw/app\\app (1842).jpg',
#  './test/train_raw/app\\app (1843).jpg',
#  './test/train_raw/app\\app (1844).jpg',
#  './test/train_raw/app\\app (1845).jpg',
#  './test/train_raw/app\\app (1846).jpg',
#  './test/train_raw/app\\app (1847).jpg',
#  './test/train_raw/app\\app (1848).jpg',
#  './test/train_raw/app\\app (1849).jpg',
#  './test/train_raw/app\\app (185).jpg',
#  './test/train_raw/app\\app (1850).jpg',
#  './test/train_raw/app\\app (1851).jpg',
#  './test/train_raw/app\\app (1852).jpg',
#  './test/train_raw/app\\app (1853).jpg',
#  './test/train_raw/app\\app (1854).jpg',
#  './test/train_raw/app\\app (1855).jpg',
#  './test/train_raw/app\\app (1856).jpg',
#  './test/train_raw/app\\app (1857).jpg',
#  './test/train_raw/app\\app (1858).jpg',
#  './test/train_raw/app\\app (1859).jpg',
#  './test/train_raw/app\\app (186).jpg',
#  './test/train_raw/app\\app (1860).jpg',
#  './test/train_raw/app\\app (1861).jpg',
#  './test/train_raw/app\\app (1862).jpg',
#  './test/train_raw/app\\app (1863).jpg',
#  './test/train_raw/app\\app (1864).jpg',
#  './test/train_raw/app\\app (1865).jpg',
#  './test/train_raw/app\\app (1866).jpg',
#  './test/train_raw/app\\app (1867).jpg',
#  './test/train_raw/app\\app (1868).jpg',
#  './test/train_raw/app\\app (1869).jpg',
#  './test/train_raw/app\\app (187).jpg',
#  './test/train_raw/app\\app (1870).jpg',
#  './test/train_raw/app\\app (1871).jpg',
#  './test/train_raw/app\\app (1872).jpg',
#  './test/train_raw/app\\app (1873).jpg',
#  './test/train_raw/app\\app (1874).jpg',
#  './test/train_raw/app\\app (1875).jpg',
#  './test/train_raw/app\\app (1876).jpg',
#  './test/train_raw/app\\app (1877).jpg',
#  './test/train_raw/app\\app (1878).jpg',
#  './test/train_raw/app\\app (1879).jpg',
#  './test/train_raw/app\\app (188).jpg',
#  './test/train_raw/app\\app (1880).jpg',
#  './test/train_raw/app\\app (1881).jpg',
#  './test/train_raw/app\\app (1882).jpg',
#  './test/train_raw/app\\app (1883).jpg',
#  './test/train_raw/app\\app (1884).jpg',
#  './test/train_raw/app\\app (1885).jpg',
#  './test/train_raw/app\\app (1886).jpg',
#  './test/train_raw/app\\app (1887).jpg',
#  './test/train_raw/app\\app (1888).jpg',
#  './test/train_raw/app\\app (1889).jpg',
#  './test/train_raw/app\\app (189).jpg',
#  './test/train_raw/app\\app (1890).jpg',
#  './test/train_raw/app\\app (1891).jpg',
#  './test/train_raw/app\\app (1892).jpg',
#  './test/train_raw/app\\app (1893).jpg',
#  './test/train_raw/app\\app (1894).jpg',
#  './test/train_raw/app\\app (1895).jpg',
#  './test/train_raw/app\\app (1896).jpg',
#  './test/train_raw/app\\app (1897).jpg',
#  './test/train_raw/app\\app (1898).jpg',
#  ...]

# %%
from skimage.transform import rescale, resize
from skimage import color
from skimage.io import imread, imsave
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
image = imread(train_app_list[0])
plt.imshow(image)

# %%
import numpy as np

# %%
imsave('./tmp.png', image)

# %%
tmp = imread('tmp.png')
print(tmp.shape)
plt.imshow(tmp)
# Out:
# (292, 292, 3)

# %%
train_app_list[0].split('/')[-1][:-4]
# Out:
# 'app\\app (1)'

# %%
def img_load(img):
#    img = color.rgb2gray(img)
    return img

# %%
from tqdm.notebook import tqdm

def convert_train_app():
    train_app_list = glob('./test/train_raw/app/*')
    for each in tqdm(train_app_list):
        img = imread(each)
        img_loaded = img_load(img)
        save_name = './test/train/' + each.split('/')[-1][:-4] + '.png'
        imsave(save_name, img_loaded)
convert_train_app()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (2043).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (2358).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (2490).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (2562).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (2779).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (3179).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (3260).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (3279).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (3389).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (4383).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (4777).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (4979).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (5274).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (5474).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (6095).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (6412).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (6634).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (6657).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (788).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (795).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (8304).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (8970).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (9068).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (9183).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (9245).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (9572).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (9725).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (9790).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (9792).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-11-a3af186bee09>:9: UserWarning: ./test/train/app\app (9957).png is a low contrast image
#   imsave(save_name, img_loaded)

# %%
def convert_train_sam():
    train_sam_list = glob('./test/train_raw/sam/*')
    for each in tqdm(train_sam_list):
        img = imread(each)
        img_loaded = img_load(img)
        save_name = './test/train/' + each.split('/')[-1][:-4] + '.png'
        imsave(save_name, img_loaded)
convert_train_sam()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# <ipython-input-12-b472ed8339db>:7: UserWarning: ./test/train/sam\sam (1032).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-12-b472ed8339db>:7: UserWarning: ./test/train/sam\sam (1122).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-12-b472ed8339db>:7: UserWarning: ./test/train/sam\sam (4657).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-12-b472ed8339db>:7: UserWarning: ./test/train/sam\sam (6060).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-12-b472ed8339db>:7: UserWarning: ./test/train/sam\sam (6062).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-12-b472ed8339db>:7: UserWarning: ./test/train/sam\sam (7485).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-12-b472ed8339db>:7: UserWarning: ./test/train/sam\sam (8423).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-12-b472ed8339db>:7: UserWarning: ./test/train/sam\sam (938).png is a low contrast image
#   imsave(save_name, img_loaded)

# %%
def convert_test_app():
    test_app_list = glob('./test/test_raw/app/*')
    for each in tqdm(test_app_list):
        img = imread(each)
        img_loaded = img_load(img)
        save_name = './test/test/' + each.split('/')[-1][:-4] + '.png'
        imsave(save_name, img_loaded)
convert_test_app()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# <ipython-input-13-76fc3924aec7>:7: UserWarning: ./test/test/app\app (10182).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-13-76fc3924aec7>:7: UserWarning: ./test/test/app\app (11362).png is a low contrast image
#   imsave(save_name, img_loaded)

# %%
def convert_test_sam():
    test_sam_list = glob('./test/test_raw/sam/*')
    for each in tqdm(test_sam_list):
        img = imread(each)
        img_loaded = img_load(img)
        save_name = './test/test/' + each.split('/')[-1][:-4] + '.png'
        imsave(save_name, img_loaded)
convert_test_sam()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# <ipython-input-14-6d6485f70e4f>:7: UserWarning: ./test/test/sam\sam (10555).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-14-6d6485f70e4f>:7: UserWarning: ./test/test/sam\sam (11243).png is a low contrast image
#   imsave(save_name, img_loaded)
# <ipython-input-14-6d6485f70e4f>:7: UserWarning: ./test/test/sam\sam (11814).png is a low contrast image
#   imsave(save_name, img_loaded)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
import keras

np.random.seed(42)

# %%
keras.__version__
# Out:
# '2.7.0'

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(
                    './test/train'
                    , target_size = (292, 292)
                    , batch_size = 3
                    , class_mode = 'categorical')

test_datagen = ImageDataGenerator(rescale = 1./255)

test_generator = test_datagen.flow_from_directory(
                    './test/test'
                    , target_size = (292, 292)
                    , batch_size = 3
                    , class_mode = 'categorical')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 4000 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3,3)
                , activation = 'relu'
                , input_shape = (292, 292, 3)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dense(2, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 290, 290, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 288, 288, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 144, 144, 64)     0
#  )
#
#  flatten (Flatten)           (None, 1327104)           0
#
#  dense (Dense)               (None, 128)               169869440
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 169,889,090
# Trainable params: 169,889,090
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy'
            , optimizer = 'adam'
            , metrics = ['accuracy'])

# %%
hist = model.fit_generator(
        train_generator
        , steps_per_epoch = 15
        , epochs = 50
        , validation_data = test_generator
        , validation_steps = 5)
# Out:
# <ipython-input-8-decb3469f086>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(
# Epoch 1/50
# 15/15 [==============================] - 26s 2s/step - loss: 15.6570 - accuracy: 0.4667 - val_loss: 1.7907 - val_accuracy: 0.8000
# Epoch 2/50
# 15/15 [==============================] - 24s 2s/step - loss: 1.3850 - accuracy: 0.6222 - val_loss: 1.5298 - val_accuracy: 0.6667
# Epoch 3/50
# 15/15 [==============================] - 25s 2s/step - loss: 1.0002 - accuracy: 0.4000 - val_loss: 0.7494 - val_accuracy: 0.4000
# Epoch 4/50
# 15/15 [==============================] - 25s 2s/step - loss: 0.7182 - accuracy: 0.5111 - val_loss: 0.6264 - val_accuracy: 0.5333
# Epoch 5/50
# 15/15 [==============================] - 25s 2s/step - loss: 0.6466 - accuracy: 0.6222 - val_loss: 0.5744 - val_accuracy: 0.7333
# Epoch 6/50
# 15/15 [==============================] - 24s 2s/step - loss: 0.6370 - accuracy: 0.5778 - val_loss: 0.6453 - val_accuracy: 0.5333
# Epoch 7/50
# 15/15 [==============================] - 25s 2s/step - loss: 0.6179 - accuracy: 0.6444 - val_loss: 0.6142 - val_accuracy: 0.6000
# Epoch 8/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.7757 - accuracy: 0.6222 - val_loss: 0.8858 - val_accuracy: 0.4000
# Epoch 9/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.5852 - accuracy: 0.6889 - val_loss: 0.6027 - val_accuracy: 0.7333
# Epoch 10/50
# 15/15 [==============================] - 24s 2s/step - loss: 0.5929 - accuracy: 0.6667 - val_loss: 0.4619 - val_accuracy: 0.8000
# Epoch 11/50
# 15/15 [==============================] - 25s 2s/step - loss: 1.5247 - accuracy: 0.6222 - val_loss: 0.5224 - val_accuracy: 0.6667
# Epoch 12/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.5853 - accuracy: 0.7556 - val_loss: 0.7432 - val_accuracy: 0.8000
# Epoch 13/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.6392 - accuracy: 0.8000 - val_loss: 0.6643 - val_accuracy: 0.6667
# Epoch 14/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.5543 - accuracy: 0.7556 - val_loss: 0.6846 - val_accuracy: 0.6000
# Epoch 15/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.7589 - accuracy: 0.5778 - val_loss: 0.6083 - val_accuracy: 0.7333
# Epoch 16/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.6421 - accuracy: 0.5111 - val_loss: 0.6074 - val_accuracy: 0.8667
# Epoch 17/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.5654 - accuracy: 0.6889 - val_loss: 0.4764 - val_accuracy: 0.9333
# Epoch 18/50
# 15/15 [==============================] - 22s 1s/step - loss: 1.3821 - accuracy: 0.6444 - val_loss: 0.5760 - val_accuracy: 0.6667
# Epoch 19/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.9826 - accuracy: 0.8000 - val_loss: 0.4261 - val_accuracy: 0.7333
# Epoch 20/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.6053 - accuracy: 0.6444 - val_loss: 0.5563 - val_accuracy: 0.7333
# Epoch 21/50
# 15/15 [==============================] - 26s 2s/step - loss: 0.5521 - accuracy: 0.6667 - val_loss: 0.6037 - val_accuracy: 0.8000
# Epoch 22/50
# 15/15 [==============================] - 24s 2s/step - loss: 0.5816 - accuracy: 0.7111 - val_loss: 0.6701 - val_accuracy: 0.7333
# Epoch 23/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.5214 - accuracy: 0.7778 - val_loss: 0.5892 - val_accuracy: 0.6000
# Epoch 24/50
# 15/15 [==============================] - 26s 2s/step - loss: 0.8519 - accuracy: 0.7556 - val_loss: 0.6850 - val_accuracy: 0.6000
# Epoch 25/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.6304 - accuracy: 0.6889 - val_loss: 0.8353 - val_accuracy: 0.5333
# Epoch 26/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.5677 - accuracy: 0.7111 - val_loss: 0.5287 - val_accuracy: 0.6667
# Epoch 27/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.5602 - accuracy: 0.6889 - val_loss: 0.4811 - val_accuracy: 0.7333
# Epoch 28/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.5905 - accuracy: 0.6222 - val_loss: 0.6414 - val_accuracy: 0.6667
# Epoch 29/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.5169 - accuracy: 0.7556 - val_loss: 0.5062 - val_accuracy: 0.8000
# Epoch 30/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.6281 - accuracy: 0.6667 - val_loss: 0.6741 - val_accuracy: 0.7333
# Epoch 31/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.6153 - accuracy: 0.7333 - val_loss: 0.4367 - val_accuracy: 0.7333
# Epoch 32/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.5789 - accuracy: 0.6667 - val_loss: 0.5970 - val_accuracy: 0.6667
# Epoch 33/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.8127 - accuracy: 0.7778 - val_loss: 0.6516 - val_accuracy: 0.6000
# Epoch 34/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.6243 - accuracy: 0.6444 - val_loss: 0.6781 - val_accuracy: 0.5333
# Epoch 35/50
# 15/15 [==============================] - 22s 1s/step - loss: 0.6284 - accuracy: 0.6000 - val_loss: 0.5388 - val_accuracy: 0.7333
# Epoch 36/50
# 15/15 [==============================] - 21s 1s/step - loss: 0.5997 - accuracy: 0.6667 - val_loss: 0.6670 - val_accuracy: 0.4667
# Epoch 37/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.6308 - accuracy: 0.6444 - val_loss: 0.5287 - val_accuracy: 0.6000
# Epoch 38/50
# 15/15 [==============================] - 25s 2s/step - loss: 0.5264 - accuracy: 0.6222 - val_loss: 0.6679 - val_accuracy: 0.7333
# Epoch 39/50
# 15/15 [==============================] - 30s 2s/step - loss: 0.7381 - accuracy: 0.6889 - val_loss: 0.6036 - val_accuracy: 0.5333
# Epoch 40/50
# 15/15 [==============================] - 26s 2s/step - loss: 0.5442 - accuracy: 0.6667 - val_loss: 0.6637 - val_accuracy: 0.6000
# Epoch 41/50
# 15/15 [==============================] - 26s 2s/step - loss: 0.5300 - accuracy: 0.6889 - val_loss: 0.3881 - val_accuracy: 0.8667
# Epoch 42/50
# 15/15 [==============================] - 30s 2s/step - loss: 0.5624 - accuracy: 0.6667 - val_loss: 0.4659 - val_accuracy: 0.8000
# Epoch 43/50
# 15/15 [==============================] - 26s 2s/step - loss: 0.6116 - accuracy: 0.6222 - val_loss: 0.4093 - val_accuracy: 0.7333
# Epoch 44/50
# 15/15 [==============================] - 24s 2s/step - loss: 0.6077 - accuracy: 0.5556 - val_loss: 0.6248 - val_accuracy: 0.4000
# Epoch 45/50
# 15/15 [==============================] - 23s 2s/step - loss: 0.5113 - accuracy: 0.7333 - val_loss: 0.4427 - val_accuracy: 0.7333
# Epoch 46/50
# 15/15 [==============================] - 24s 2s/step - loss: 0.8579 - accuracy: 0.6889 - val_loss: 0.4710 - val_accuracy: 0.8000
# Epoch 47/50
# 15/15 [==============================] - 28s 2s/step - loss: 0.6664 - accuracy: 0.6000 - val_loss: 0.4814 - val_accuracy: 0.6667
# Epoch 48/50
# 15/15 [==============================] - 25s 2s/step - loss: 0.5727 - accuracy: 0.6667 - val_loss: 0.5353 - val_accuracy: 0.7333
# Epoch 49/50
# 15/15 [==============================] - 26s 2s/step - loss: 0.6850 - accuracy: 0.6444 - val_loss: 0.5124 - val_accuracy: 0.6000
# Epoch 50/50
# 15/15 [==============================] - 25s 2s/step - loss: 0.4990 - accuracy: 0.7111 - val_loss: 0.8387 - val_accuracy: 0.4667

# %%
plt.figure(figsize = (12,6))
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label = 'val_loss')
plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label = 'val_acc')
plt.ylim(0, 1.2)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dea35b31625f> in <module>
# ----> 1 plt.figure(figsize = (12,6))
#       2 plt.plot(hist.history['loss'], label = 'loss')
#       3 plt.plot(hist.history['val_loss'], label = 'val_loss')
#       4 plt.plot(hist.history['accuracy'], label = 'acc')
#       5 plt.plot(hist.history['val_accuracy'], label = 'val_acc')
#
# NameError: name 'plt' is not defined

# %%
scores = model.evaluate(test_generator, steps = 5)
print('%s: %.2f%%' %(model.metrics_names[1], scores[1] * 100))
# Out:
# 5/5 [==============================] - 1s 167ms/step - loss: 0.3729 - accuracy: 0.9333
# accuracy: 93.33%

# %%
model.predict(test_generator)
# Out:
# array([[0.6747942 , 0.32520583],
#        [0.2972876 , 0.70271236],
#        [0.51323026, 0.48676974],
#        ...,
#        [0.56368697, 0.43631303],
#        [0.6045218 , 0.3954782 ],
#        [0.31471768, 0.6852823 ]], dtype=float32)

# %%
n = 1
def show_prediction_result(n):
    img = imread(test_generator.filepaths[n])
    pred = model.predict(np.expand_dims(color.gray2rgb(img), axis = 0))
    title = 'Predict :' + str(np.argmax(pred))
    plt.imshow(img/255, cmap = 'gray')
    plt.title(title)
    plt.show()
    
show_prediction_result(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-15c913431bad> in <module>
#       8     plt.show()
#       9
# ---> 10 show_prediction_result(n)
#
# <ipython-input-11-15c913431bad> in show_prediction_result(n)
#       1 n = 1
#       2 def show_prediction_result(n):
# ----> 3     img = imread(test_generator.filepaths[n])
#       4     pred = model.predict(np.expand_dims(color.gray2rgb(img), axis = 0))
#       5     title = 'Predict :' + str(np.argmax(pred))
#
# NameError: name 'imread' is not defined

# %%
show_prediction_result(1200)
