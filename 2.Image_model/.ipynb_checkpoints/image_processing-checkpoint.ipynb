# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# row, columns 길게 조회할 수 있게 옵션 걸어두기
pd.options.display.max_info_columns =200
pd.options.display.max_columns = 200
pd.options.display.max_info_rows =999
pd.options.display.max_rows = 999

# import warnings
# warnings.filterwarnings(action='ignore')

# %%
# 한글글꼴
import warnings
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttfn"
if platform.system() == 'Darwin':
    font_name = 'AppleGothic'
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    font_name = font_manager.FontProperties(fname="/usr/share/fonts/nanumfont/NanumGothic.ttf")
    rc('font', family="NanumGothic")

# warnings.simplefilter(action='ignore')

# %% [markdown]
# # dataset의 이미지에 카테고리 붙이기

# %%
dataset = pd.read_csv('/Users/ppangppang/Desktop/ssac/Final_project/0.Data_원본/data(ad)/dataset.csv')
dataset
# Out:
#         label       day  hour  c_user_gender  c_user_age  \
# 0           0  20210831     5              0           0
# 1           0  20210831     5              1          46
# 2           0  20210831     5              1          26
# 3           0  20210831     5              2          45
# 4           0  20210831     5              1          34
# ...       ...       ...   ...            ...         ...
# 853863      0  20210831     9              1          18
# 853864      0  20210831     9              2          40
# 853865      0  20210831     9              2          36
# 853866      0  20210831     9              1          54
# 853867      0  20210831     9              1          18
#
#         user_following_count  user_pay_count  user_parcel_post_count  \
# 0                         28               0                       0
# 1                          0               0                       0
# 2                          9               0                       0
# ...

# %%
df = dataset.copy()
df = df[['c_content_category_id_1','c_content_category_id_2','c_content_category_id_3','content_img_url']]
df = df.fillna(0)
df[['c_content_category_id_1','c_content_category_id_2','c_content_category_id_3']] =df[['c_content_category_id_1','c_content_category_id_2','c_content_category_id_3']].astype(int)
df.rename(columns={'c_content_category_id_1':'category_id_1','c_content_category_id_2':'category_id_2','c_content_category_id_3':'category_id_3'},inplace=True)
df
# Out:
#         category_id_1  category_id_2  category_id_3  \
# 0                 600         600700      600700001
# 1                 750         750610      750610100
# 2                 750         750610      750610100
# 3                 810         810200      810200300
# 4                 600         600100      600100006
# ...               ...            ...            ...
# 853863            600         600100      600100006
# 853864            430         430300      430300999
# 853865            320         320080      320080999
# 853866            420         420200      420200999
# 853867            600         600700      600700001
#
#                                           content_img_url
# 0       https://media.bunjang.co.kr/product/137083455_...
# 1       https://media.bunjang.co.kr/product/162622860_...
# 2       https://media.bunjang.co.kr/product/162622860_...
# 3       https://media.bunjang.co.kr/product/149111357_...
# ...

# %%
cat = pd.read_csv('/Users/ppangppang/Desktop/ssac/Final_project/2.Processed/data/ad_category_merge.csv')
cat = cat[['category_id_1','category_id_2','category_id_3','대분류명','중분류명']]
cat
# Out:
#       category_id_1  category_id_2  category_id_3  대분류명     중분류명
# 0               600         600100      600100006  전자제품  컴퓨터,노트북
# 1               600         600700      600700001  전자제품      핸드폰
# 2               600         600700      600700001  전자제품      핸드폰
# 3               600         600700      600700001  전자제품      핸드폰
# 4               750         750200      750200700   중고차      중고차
# ...             ...            ...            ...   ...      ...
# 1422            600         600700      600700001  전자제품      핸드폰
# 1423            600         600700      600700001  전자제품      핸드폰
# 1424            600         600700      600700001  전자제품      핸드폰
# 1425            600         600700      600700001  전자제품      핸드폰
# 1426            600         600700      600700001  전자제품      핸드폰
#
# [1427 rows x 5 columns]

# %%
image_link = pd.merge(df,cat,how='left',on=('category_id_1','category_id_2','category_id_3'))
image_link
# Out:
#            category_id_1  category_id_2  category_id_3  \
# 0                    600         600700      600700001
# 1                    600         600700      600700001
# 2                    600         600700      600700001
# 3                    600         600700      600700001
# 4                    600         600700      600700001
# ...                  ...            ...            ...
# 192651793            600         600700      600700001
# 192651794            600         600700      600700001
# 192651795            600         600700      600700001
# 192651796            600         600700      600700001
# 192651797            600         600700      600700001
#
#                                              content_img_url  대분류명 중분류명
# 0          https://media.bunjang.co.kr/product/137083455_...  전자제품  핸드폰
# 1          https://media.bunjang.co.kr/product/137083455_...  전자제품  핸드폰
# 2          https://media.bunjang.co.kr/product/137083455_...  전자제품  핸드폰
# ...
